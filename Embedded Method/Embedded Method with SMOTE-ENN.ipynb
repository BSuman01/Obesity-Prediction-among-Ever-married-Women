# %% [markdown]
# # Embedded Method With SMOTE-ENN

# %% [markdown]
# ## Import Essential Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from imblearn.combine import SMOTEENN
from sklearn.model_selection import train_test_split , GridSearchCV , KFold
from sklearn.linear_model import Lasso, LassoCV
from sklearn.feature_selection import SelectKBest
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, make_scorer, confusion_matrix, log_loss
from sklearn.inspection import permutation_importance
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## Import Data

# %%
# Import  the SPSS data file
df=pd.read_spss("E:\Data Analysis\BDHS_2017-2018.sav")
# Displaying the first 5 rows of the DataFrame
df.head()
# Out:
#     V013      V024   V025       V106          V701   V130  V151  \
# 0  15-19  Rajshahi  Rural  Secondary  No education  Islam  Male
# 1  45-49   Rangpur  Urban    Primary  No education  Islam  Male
# 2  15-19    Khulna  Rural  Secondary       Primary  Islam  Male
# 3  40-44   Barisal  Urban    Primary       Primary  Islam  Male
# 4  25-29   Barisal  Rural  Secondary        Higher  Islam  Male
#
#                   V201 V123 V124  ...     V190    V190A      V113      V116  \
# 0             No child   No   No  ...  Poorest  Poorest  Improved  Improved
# 1  More than two child   No   No  ...  Poorest  Poorest  Improved  Improved
# 2            One child   No   No  ...   Poorer   Poorer  Improved  Improved
# 3  More than two child   No   No  ...  Poorest  Poorest  Improved  Improved
# 4            One child   No   No  ...   Richer  Richest  Improved  Improved
#
#          V161          V213 V404                           V743A  \
# 0  Solid fuel  No or unsure   No  Respondent and husband/partner
# 1  Solid fuel  No or unsure   No  Respondent and husband/partner
# 2  Solid fuel  No or unsure  Yes  Respondent and husband/partner
# 3  Solid fuel  No or unsure   No  Respondent and husband/partner
# 4  Solid fuel           Yes   No  Respondent and husband/partner
#
#                   V312                BMI2
# 0       Modern methods  Underweight/Normal
# 1  Traditional methods  Underweight/Normal
# 2       Modern methods  Underweight/Normal
# 3            Not using  Underweight/Normal
# 4            Not using  Underweight/Normal
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Get some Basic Information

# %%
# Displaying a summary of the DataFrame, including the number of non-null entries and data types for each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16303 entries, 0 to 16302
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V013    16303 non-null  category
#  1   V024    16303 non-null  category
#  2   V025    16303 non-null  category
#  3   V106    16303 non-null  category
#  4   V701    16303 non-null  category
#  5   V130    16303 non-null  category
#  6   V151    16303 non-null  category
#  7   V201    16303 non-null  category
#  8   V123    16303 non-null  category
#  9   V124    16303 non-null  category
#  10  V125    16303 non-null  category
#  11  V119    16303 non-null  category
#  12  V122    16303 non-null  category
#  13  V121    16303 non-null  category
#  14  V159    16303 non-null  category
#  15  V716    16303 non-null  category
#  16  V704    16303 non-null  category
#  17  V190    16303 non-null  category
#  18  V190A   16303 non-null  category
#  19  V113    16303 non-null  category
#  20  V116    16303 non-null  category
#  21  V161    16303 non-null  category
#  22  V213    16303 non-null  category
#  23  V404    16303 non-null  category
#  24  V743A   16303 non-null  category
#  25  V312    16303 non-null  category
#  26  BMI2    16303 non-null  category
# dtypes: category(27)
# memory usage: 434.4 KB

# %%
# Checking missing values
df.isnull().sum().sum()
# Out:
# 0

# %%
# Checking the dimensions of the DataFrame
df.shape
# Out:
# (16303, 27)

# %%
# Displaying the column labels (names) of the DataFrame
df.columns
# Out:
# Index(['V013', 'V024', 'V025', 'V106', 'V701', 'V130', 'V151', 'V201', 'V123',
#        'V124', 'V125', 'V119', 'V122', 'V121', 'V159', 'V716', 'V704', 'V190',
#        'V190A', 'V113', 'V116', 'V161', 'V213', 'V404', 'V743A', 'V312',
#        'BMI2'],
#       dtype='object')

# %%
# Counting the frequency of each unique value in the 'BMI2' column
df.BMI2.value_counts()
# Out:
# BMI2
# Underweight/Normal    10951
# Overweight/Obese       5352
# Name: count, dtype: int64

# %% [markdown]
# ## Feature Transformation

# %%
# Transform the selected features
V013 = {'15-19': 1, '20-24': 2,'25-29':3,'30-34':4,'35-39':5,'40-44':6,'45-49':7}
df['V013'] = df['V013'].map(V013)
V024 = {'Barisal': 1, 'Chittagong': 2,'Dhaka':3,'Khulna':4,'Mymensingh':5,'Rajshahi':6,'Rangpur':7,'Sylhet':8}
df['V024'] = df['V024'].map(V024)
V025 = {'Urban': 1, 'Rural': 2}
df['V025'] = df['V025'].map(V025)
V106 = {'No education': 0, 'Primary': 1,'Secondary':2,'Higher':3}
df['V106'] = df['V106'].map(V106)
V701= {'No education': 0, 'Primary': 1,'Secondary':2,'Higher':3,"Don't know":4}
df['V701'] = df['V701'].map(V701)
V130 = {'Islam': 0, 'Hinduism': 1,'Buddhism':2,'Christianity':3}
df['V130'] = df['V130'].map(V130)
V151= {'Male': 1, 'Female': 2}
df['V151'] = df['V151'].map(V151)
V201= {'No child': 0, 'One child': 1,'Two child':2,'More than two child':3}
df['V201'] = df['V201'].map(V201)
V123= {'No': 0, 'Yes': 1}
df['V123'] = df['V123'].map(V123)
V124= {'No': 0, 'Yes': 1}
df['V124'] = df['V124'].map(V124)
V125= {'No': 0, 'Yes': 1}
df['V125'] = df['V125'].map(V125)
V119= {'No': 0, 'Yes': 1}
df['V119'] = df['V119'].map(V119)
V122= {'No': 0, 'Yes': 1}
df['V122'] = df['V122'].map(V122)
V121= {'No': 0, 'Yes': 1}
df['V121'] = df['V121'].map(V121)
V159= {'Not at all': 0, 'Less than once a week': 1,'At least once a week':2,'Almost every day':3}
df['V159'] = df['V159'].map(V159)
V716= {'Unemployed': 0, 'Agriculture': 1,'Business':2,'Labor/ Service':3,'Job':4}
df['V716'] = df['V716'].map(V716)
V704= {'Unemployed': 0, 'Agriculture': 1,'Business':2,'Labor/ Service':3,'Job':4}
df['V704'] = df['V704'].map(V704)
V190= {'Poorest': 1, 'Poorer': 2,'Middle':3,'Richer':4,'Richest':5}
df['V190'] = df['V190'].map(V190)
V190A= {'Poorest': 1, 'Poorer': 2,'Middle':3,'Richer':4,'Richest':5}
df['V190A'] = df['V190A'].map(V190A)
V113= {'Improved': 1, 'Unimproved': 2}
df['V113'] = df['V113'].map(V113)
V116= {'Improved': 1, 'Unimproved': 2}
df['V116'] = df['V116'].map(V116)
V161= {'Solid fuel': 0, 'Clean fuel': 1}
df['V161'] = df['V161'].map(V161)
V213= {'No or unsure': 0, 'Yes': 1}
df['V213'] = df['V213'].map(V213)
V404= {'No': 0, 'Yes': 1}
df['V404'] = df['V404'].map(V404)
V743A= {'Respondent alone': 1, 'Respondent and husband/partner': 2, "Respondent and other's person": 3}
df['V743A'] = df['V743A'].map(V743A)
V312= {'Not using': 0, 'Modern methods': 1,'Traditional methods':2}
df['V312'] = df['V312'].map(V312)
BMI2= {'Underweight/Normal': 0, 'Overweight/Obese': 1}
df['BMI2'] = df['BMI2'].map(BMI2)

# %%
# Displaying the first 5 rows of the DataFrame after transformation
df.head()
# Out:
#   V013 V024 V025 V106 V701 V130 V151 V201 V123 V124  ... V190 V190A V113 V116  \
# 0    1    6    2    2    0    0    1    0    0    0  ...    1     1    1    1
# 1    7    7    1    1    0    0    1    3    0    0  ...    1     1    1    1
# 2    1    4    2    2    1    0    1    1    0    0  ...    2     2    1    1
# 3    6    1    1    1    1    0    1    3    0    0  ...    1     1    1    1
# 4    3    1    2    2    3    0    1    1    0    0  ...    4     5    1    1
#
#   V161 V213 V404 V743A V312 BMI2
# 0    0    0    0     2    1    0
# 1    0    0    0     2    2    0
# 2    0    0    1     2    1    0
# 3    0    0    0     2    0    0
# 4    0    1    0     2    0    0
#
# [5 rows x 27 columns]

# %%
# Checking missing values after transformation
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Define Explanatory and Outcome Variable

# %%
# Drop the Outcome variable from the DataFrame in order to create explanatory variavle
x=df.drop(["BMI2"],axis=1)
y=df["BMI2"]

# %%
# Checking the dimensions of the explanatory and outcome variable
x.shape, y.shape
# Out:
# ((16303, 26), (16303,))

# %% [markdown]
# ## Explanatory Data Analysis (EDA)

# %% [markdown]
# ### BMI2 Graph

# %%
# Calculate the counts for each category in y
counts = np.bincount(y)

# Set up the figure and 3D axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Define the X, Y, and Z coordinates for the bars
X = np.arange(len(counts))  # [0, 1] for two categories
Y = np.zeros_like(X)  # Y values are all zeros, used just for plotting
Z = np.zeros_like(X)  # Z values are the base of the bars, all zeros

# Define the width, depth, and height of the bars
dx = np.ones_like(X)
dy = np.ones_like(Y)
dz = counts

# Create the bars
ax.bar3d(X, Y, Z, dx, dy, dz, color=['cyan', 'magenta'], zsort='average')

# Set labels and title
ax.set_xticks(X)
ax.set_xticklabels(BMI2)
# Set labels and title with Times New Roman font style
font = {'fontname': 'Times New Roman'}
# Show the plot
plt.show()

# %% [markdown]
# ### Correlation

# %%
# Calculating and displaying the correlation matrix, showing the correlation coefficients between the features of the DataFrame
corr=df.corr()
corr
# Out:
#            V013      V024      V025      V106      V701      V130      V151  \
# V013   1.000000  0.012270  0.000005 -0.372709 -0.180281  0.041279 -0.016666
# V024   0.012270  1.000000  0.072954 -0.084455 -0.084267  0.055474 -0.079159
# V025   0.000005  0.072954  1.000000 -0.150652 -0.178218  0.002744  0.042323
# V106  -0.372709 -0.084455 -0.150652  1.000000  0.624033  0.037122  0.034919
# V701  -0.180281 -0.084267 -0.178218  0.624033  1.000000  0.057236  0.045746
# V130   0.041279  0.055474  0.002744  0.037122  0.057236  1.000000 -0.053993
# V151  -0.016666 -0.079159  0.042323  0.034919  0.045746 -0.053993  1.000000
# V201   0.628503  0.015849  0.085681 -0.406391 -0.290724 -0.042693  0.004826
# V123   0.057086  0.147911  0.112747  0.043280  0.041009  0.024064 -0.091827
# V124  -0.008857  0.066598 -0.055957  0.225866  0.256817  0.009224 -0.066338
# V125   0.014769  0.001107 -0.065821  0.069399  0.066194 -0.006172 -0.014038
col10 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_b109f_row1_col15, #T_b109f_row8_col15, #T_b109f_row10_col1, #T_b109f_row11_col10, #T_b109f_row13_col5, #T_b109f_row14_col5, #T_b109f_row15_col24, #T_b109f_row19_col26, #T_b109f_row24_col26 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_b109f_row1_col17, #T_b109f_row1_col18, #T_b109f_row1_col25, #T_b109f_row3_col26, #T_b109f_row6_col13, #T_b109f_row9_col26, #T_b109f_row13_col23, #T_b109f_row21_col25, #T_b109f_row23_col25 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_b109f_row1_col19, #T_b109f_row3_col5, #T_b109f_row7_col19, #T_b109f_row12_col20, #T_b109f_row19_col1, #T_b109f_row23_col19 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_b109f_row1_col22, #T_b109f_row8_col21, #T_b109f_row10_col9, #T_b109f_row17_col23, #T_b109f_row20_col22, #T_b109f_row24_col25 {
#   background-color: #84a7

# %% [markdown]
# ## Feature Selection: Embedded Method (LASSO)

# %%
# Initialize a Lasso model with an alpha value 0.01 regularization strength
lasso_model = Lasso(alpha=0.01) 
lasso_model.fit(x,y)
# Out:
# Lasso(alpha=0.01)

# %%
# Retrieve the coefficients of the features from the fitted Lasso model
feature_coefs = lasso_model.coef_
# Create a DataFrame to display the feature names alongside their corresponding Lasso coefficients
coefficients_df = pd.DataFrame({
    'Feature': x.columns,
    'Lasso Coefficient': feature_coefs
})
print(coefficients_df)
# Out:
#    Feature  Lasso Coefficient
# 0     V013           0.040525
# 1     V024          -0.010544
# 2     V025          -0.002007
# 3     V106           0.015682
# 4     V701           0.016351
# 5     V130          -0.000000
# 6     V151          -0.000000
# 7     V201           0.001406
# 8     V123          -0.000000
# 9     V124           0.000000
# 10    V125           0.000000
# 11    V119          -0.000000
# 12    V122           0.041700
# 13    V121           0.000000
# 14    V159           0.012575
# 15    V716          -0.000000
# 16    V704           0.007101
# 17    V190           0.058330
# 18   V190A           0.000000
# 19    V113          -0.000000
# 20    V116          -0.000000
# 21    V161           0.000250
# 22    V213           0.000000
# 23    V404          -0.029117
# 24   V743A          -0.000000
# 25    V312           0.000000

# %%
# Identify the features that have non-zero coefficients in the Lasso model
important_features = x.columns[feature_coefs != 0]
# Display the important features
important_features
# Out:
# Index(['V013', 'V024', 'V025', 'V106', 'V701', 'V201', 'V122', 'V159', 'V704',
#        'V190', 'V161', 'V404'],
#       dtype='object')

# %%
# Create a new DataFrame containing only the important features
x_selected = x[important_features]

# %% [markdown]
# ## Dataset Balancing (SMOTE-ENN)

# %%
# Applying SMOTE-ENN to handle class imbalance to the selected features
smote_enn = SMOTEENN(sampling_strategy="auto", random_state=42)
x_resampled, y_resampled = smote_enn.fit_resample(x_selected, y)
# Checking the dimensions of the explanatory and outcome variable after resampling
x_resampled.shape , y_resampled.shape
# Out:
# ((9136, 12), (9136,))

# %%
# Counting the frequency of each unique value in the 'BMI2' column after resampling
y_resampled.value_counts()
# Out:
# BMI2
# 1    4621
# 0    4515
# Name: count, dtype: int64

# %% [markdown]
# ## Train-Test Spliting

# %%
# Spliting the data set into training and testing subsets
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, random_state=42, stratify=y_resampled, test_size=.2)

# %%
# Checking the dimensions of the training and testing subsets
x_train.shape, x_test.shape
# Out:
# ((7308, 12), (1828, 12))

# %%
# Checking the dimensions of the training and testing subsets
y_train.shape, y_test.shape
# Out:
# ((7308,), (1828,))

# %%
x_train.head()
# Out:
#      V013 V024 V025 V106 V701 V201 V122 V159 V704 V190 V161 V404
# 2668    1    1    1    1    1    1    0    0    3    1    0    1
# 8364    3    2    1    1    1    1    0    0    3    4    1    0
# 8870    2    3    1    2    2    0    1    2    1    4    0    0
# 1698    5    7    2    1    1    2    0    1    1    2    0    0
# 2805    2    8    2    1    2    3    0    0    3    1    0    1

# %%
y_train.head()
# Out:
# 2668    0
# 8364    1
# 8870    1
# 1698    0
# 2805    0
# Name: BMI2, dtype: category
# Categories (2, int64): [1, 0]

# %% [markdown]
# ## (Default) Classification Algorithm in Machine Learning

# %% [markdown]
# ### 1. Support Vector Machine (SVM)

# %%
# Initialize the SVM model
model_svm=SVC()
model_svm.fit(x_train, y_train) 
y_pred = model_svm.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82       903
#            1       0.83      0.82      0.82       925
#
#     accuracy                           0.82      1828
#    macro avg       0.82      0.82      0.82      1828
# weighted avg       0.82      0.82      0.82      1828

# %%
# Printing the default parameters
print(model_svm.get_params())
# Out:
# {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': False, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_svm= accuracy_score(y_test, y_pred)
precision_svm = precision_score(y_test, y_pred)
recall_svm = recall_score(y_test, y_pred)
f1_svm = f1_score(y_test, y_pred)
kappa_svm = cohen_kappa_score(y_test, y_pred)
specificity_svm = specificity_score(y_test, y_pred)
log_loss_svm = log_loss(y_test, y_pred)
roc_auc_score_svm = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_svm)
print("Precision:", precision_svm)
print("Recall:", recall_svm)
print("F1 Score:", f1_svm)
print("Kappa:",kappa_svm)
print("Specificity:", specificity_svm)
print("AUC:", roc_auc_score_svm)
print("Log Loss:", log_loss_svm)
# Out:
# Accuracy: 0.8227571115973742
# Precision: 0.8262757871878393
# Recall: 0.8227027027027027
# F1 Score: 0.8244853737811484
# Kappa: 0.645481546570831
# Specificity: 0.82281284606866
# AUC: 0.8227577743856813
# Log Loss: 6.388481235270217

# %% [markdown]
# ### 2. Logistic Regression (LR)

# %%
# Initialize the SVM model
model_lr=LogisticRegression()
model_lr.fit(x_train, y_train) 
y_pred = model_lr.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       903
#            1       0.81      0.79      0.80       925
#
#     accuracy                           0.80      1828
#    macro avg       0.80      0.80      0.80      1828
# weighted avg       0.80      0.80      0.80      1828

# %%
# Printing the default parameters
print(model_lr.get_params())
# Out:
# {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'auto', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_lr= accuracy_score(y_test, y_pred)
precision_lr = precision_score(y_test, y_pred)
recall_lr = recall_score(y_test, y_pred)
f1_lr = f1_score(y_test, y_pred)
kappa_lr = cohen_kappa_score(y_test, y_pred)
specificity_lr = specificity_score(y_test, y_pred)
log_loss_lr = log_loss(y_test, y_pred)
roc_auc_score_lr = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_lr)
print("Precision:", precision_lr)
print("Recall:", recall_lr)
print("F1 Score:", f1_lr)
print("Kappa:", kappa_lr)
print("Specificity:", specificity_lr)
print("AUC:", roc_auc_score_lr)
print("Log Loss:", log_loss_lr)
# Out:
# Accuracy: 0.7986870897155361
# Precision: 0.8063806380638063
# Recall: 0.7924324324324324
# F1 Score: 0.7993456924754635
# Kappa: 0.5974006853783167
# Specificity: 0.805094130675526
# AUC: 0.7987632815539792
# Log Loss: 7.256052761047655

# %% [markdown]
# ### 3. Random Forest (RF)

# %%
# Initialize the SVM model
model_rf=RandomForestClassifier()
model_rf.fit(x_train, y_train) 
y_pred = model_rf.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       903
#            1       0.93      0.96      0.94       925
#
#     accuracy                           0.94      1828
#    macro avg       0.94      0.94      0.94      1828
# weighted avg       0.94      0.94      0.94      1828

# %%
# Printing the default parameters
print(model_rf.get_params())
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_rf= accuracy_score(y_test, y_pred)
precision_rf = precision_score(y_test, y_pred)
recall_rf = recall_score(y_test, y_pred)
f1_rf = f1_score(y_test, y_pred)
kappa_rf = cohen_kappa_score(y_test, y_pred)
specificity_rf = specificity_score(y_test, y_pred)
log_loss_rf = log_loss(y_test, y_pred)
roc_auc_score_rf = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_rf)
print("Precision:", precision_rf)
print("Recall:", recall_rf)
print("F1 Score:", f1_rf)
print("Kappa:", kappa_rf)
print("Specificity:", specificity_rf)
print("AUC:", roc_auc_score_rf)
print("Log Loss:", log_loss_rf)
# Out:
# Accuracy: 0.9420131291028446
# Precision: 0.927007299270073
# Recall: 0.961081081081081
# F1 Score: 0.9437367303609342
# Kappa: 0.8839574991525941
# Specificity: 0.9224806201550387
# AUC: 0.9417808506180599
# Log Loss: 2.090058675736553

# %% [markdown]
# ### 4. K-Nearest Neighbor (KNN)

# %%
# Initialize the KNN model
model_knn=KNeighborsClassifier()
model_knn.fit(x_train, y_train) 
y_pred = model_knn.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       903
#            1       0.90      0.94      0.92       925
#
#     accuracy                           0.91      1828
#    macro avg       0.91      0.91      0.91      1828
# weighted avg       0.91      0.91      0.91      1828

# %%
# Printing the default parameters
print(model_knn.get_params())
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_knn= accuracy_score(y_test, y_pred)
precision_knn = precision_score(y_test, y_pred)
recall_knn = recall_score(y_test, y_pred)
f1_knn = f1_score(y_test, y_pred)
kappa_knn = cohen_kappa_score(y_test, y_pred)
specificity_knn = specificity_score(y_test, y_pred)
log_loss_knn = log_loss(y_test, y_pred)
roc_auc_score_knn = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_knn)
print("Precision:", precision_knn)
print("Recall:", recall_knn)
print("F1 Score:", f1_knn)
print("Kappa:", kappa_knn)
print("Specificity:", specificity_knn)
print("AUC:", roc_auc_score_knn)
print("Log Loss:", log_loss_knn)
# Out:
# Accuracy: 0.9135667396061269
# Precision: 0.8957688338493293
# Recall: 0.9383783783783783
# F1 Score: 0.9165786694825766
# Kappa: 0.8270081972613504
# Specificity: 0.8881506090808416
# AUC: 0.91326449372961
# Log Loss: 3.115370478928069

# %% [markdown]
# ### 5. Extreme Gradient Boosting (XGBoost)

# %%
# Initialize the XGBoost model
model_xgb=xgb.XGBClassifier(enable_categorical=True)
model_xgb.fit(x_train, y_train)
y_pred = model_xgb.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       903
#            1       0.93      0.95      0.94       925
#
#     accuracy                           0.94      1828
#    macro avg       0.94      0.94      0.94      1828
# weighted avg       0.94      0.94      0.94      1828

# %%
# Printing the default parameters
print(model_xgb.get_params())
# Out:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': True, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': None, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': None, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_xgb= accuracy_score(y_test, y_pred)
precision_xgb = precision_score(y_test, y_pred)
recall_xgb = recall_score(y_test, y_pred)
f1_xgb = f1_score(y_test, y_pred)
kappa_xgb = cohen_kappa_score(y_test, y_pred)
specificity_xgb = specificity_score(y_test, y_pred)
log_loss_xgb = log_loss(y_test, y_pred)
roc_auc_score_xgb = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_xgb)
print("Precision:", precision_xgb)
print("Recall:", recall_xgb)
print("F1 Score:", f1_xgb)
print("Kappa:", kappa_xgb)
print("Specificity:", specificity_xgb)
print("AUC:", roc_auc_score_xgb)
print("Log Loss:", log_loss_xgb)
# Out:
# Accuracy: 0.9398249452954048
# Precision: 0.9312169312169312
# Recall: 0.9513513513513514
# F1 Score: 0.9411764705882353
# Kappa: 0.879600744861117
# Specificity: 0.9280177187153932
# AUC: 0.9396845350333723
# Log Loss: 2.1689288144435923

# %% [markdown]
# ### 6. Categorical Boosting (CatBoost)

# %%
# List of categorical feature names to be used in the model
# These features are assumed to be categorical variables in the selected features
cat_features=['V013', 'V024', 'V025', 'V106', 'V701', 'V201', 'V122', 'V159', 'V704', 'V190', 'V161', 'V404']

# %%
# Initialize the CatBoost model
model_cb=CatBoostClassifier(cat_features=cat_features)
model_cb.fit(x_train, y_train)
y_pred = model_cb.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
# Learning rate set to 0.024087
# 0:	learn: 0.6784027	total: 185ms	remaining: 3m 4s
# 1:	learn: 0.6649861	total: 227ms	remaining: 1m 53s
# 2:	learn: 0.6535930	total: 269ms	remaining: 1m 29s
# 3:	learn: 0.6416965	total: 314ms	remaining: 1m 18s
# 4:	learn: 0.6289306	total: 344ms	remaining: 1m 8s
# 5:	learn: 0.6174737	total: 371ms	remaining: 1m 1s
# 6:	learn: 0.6052384	total: 397ms	remaining: 56.4s
# 7:	learn: 0.5956595	total: 433ms	remaining: 53.6s
# 8:	learn: 0.5856642	total: 458ms	remaining: 50.5s
# 9:	learn: 0.5770431	total: 486ms	remaining: 48.1s
# 10:	learn: 0.5661288	total: 517ms	remaining: 46.5s
# 11:	learn: 0.5561928	total: 541ms	remaining: 44.6s
# 12:	learn: 0.5479601	total: 563ms	remaining: 42.7s
# 13:	learn: 0.5401272	total: 589ms	remaining: 41.5s
# 14:	learn: 0.5331989	total: 618ms	remaining: 40.6s
# 15:	learn: 0.5263136	total: 643ms	remaining: 39.6s
# 16:	learn: 0.5189698	total: 665ms	remaining: 38.5s
# 17:	learn: 0.5120580	total: 684ms	remaining: 37.3s
# 18:	learn: 0.5051093	total: 700ms	remaining: 36.2s
# 19:	learn: 0.4988444	total: 717ms	remaining: 35.1s
# 20:	learn: 0.4931159	total: 732ms	remaining: 34.1s
# 21:	learn: 0.4876514	total: 751ms	remaining: 33.4s
# 22:	learn: 0.4825194	total: 772ms	remaining: 32.8s
# 23:	learn: 0.4778150	total: 793ms	remaining: 32.2s
# 24:	learn: 0.4730156	total: 815ms	remaining: 31.8s
# 25:	learn: 0.4677371	total: 839ms	remaining: 31.4s
# 26:	learn: 0.4632215	total: 862ms	remaining: 31.1s
# 27:	learn: 0.4590016	total: 880ms	remaining: 30.6s
# 28:	learn: 0.4547692	total: 902ms	remaining: 30.2s
# 29:	learn: 0.4513857	total: 921ms	remaining: 29.8s
# 30:	learn: 0.4473979	total: 938ms	remaining: 29.3s
# 31:	learn: 0.4443712	total: 953ms	remaining: 28.8s
# 32:	learn: 0.4405079	total: 971ms	remaining: 28.4s
# 33:	learn: 0.4370626	total: 987ms	remaining: 28s
# 34:	learn: 0.4337499	total: 1s	remaining: 27.6s
# 35:	learn: 0.4306512	total: 1.02s	remaining: 27.3s
# 364:	learn: 0.2766968	total: 7.53s	remaining: 13.1s
# 365:	learn: 0.2765873	total: 7.55s	remaining: 13.1s
# 366:	learn: 0.2763431	total: 7.57s	remaining: 13.1s
# 367:	learn: 0.2762630	total: 7.59s	remaining: 13s
# 368:	learn: 0.2761816	total: 7.61s	remaining: 13s
# 369:	learn: 0.2760360	total: 7.64s	remaining: 13s
# 370:	learn: 0.2760358	total: 7.65s	remaining: 13s
# 371:	learn: 0.2759503	total: 7.67s	remaining: 12.9s
# 372:	learn: 0.2755007	total: 7.68s	remaining: 12.9s
# 373:	learn: 0.2753198	total: 7.71s	remaining: 12.9s
# 374:	learn: 0.2750546	total: 7.72s	remaining: 12.9s
# 375:	learn: 0.2748080	total: 7.75s	remaining: 12.9s
# 376:	learn: 0.2743960	total: 7.76s	remaining: 12.8s
# 377:	learn: 0.2742274	total: 7.78s	remaining: 12.8s
# 378:	learn: 0.2738897	total: 7.8s	remaining: 12.8s
# 379:	learn: 0.2736107	total: 7.82s	remaining: 12.8s
# 380:	learn: 0.2732833	total: 7.84s	remaining: 12.7s
# 381:	learn: 0.2731560	total: 7.87s	remaining: 12.7s
# 382:	learn: 0.2728906	total: 7.89s	remaining: 12.7s
# 383:	learn: 0.2725111	total: 7.91s	remaining: 12.7s
# 384:	learn: 0.2722860	total: 7.92s	remaining: 12.7s
# 385:	learn: 0.2720340	total: 7.94s	remaining: 12.6s
# 386:	learn: 0.2720018	total: 7.96s	remaining: 12.6s
# 387:	learn: 0.2719729	total: 7.98s	remaining: 12.6s
# 388:	learn: 0.2719078	total: 8s	remaining: 12.6s
# 389:	learn: 0.2716254	total: 8.02s	remaining: 12.5s
# 390:	learn: 0.2714765	total: 8.03s	remaining: 12.5s
# 391:	learn: 0.2712459	total: 8.05s	remaining: 12.5s
# 392:	learn: 0.2711020	total: 8.08s	remaining: 12.5s
# 393:	learn: 0.2709272	total: 8.1s	remaining: 12.5s
# 394:	learn: 0.2706055	total: 8.12s	remaining: 12.4s
# 395:	learn: 0.2705531	total: 8.14s	remaining: 12.4s
# 396:	learn: 0.2704803	total: 8.16s	remaining: 12.4s
# 397:	learn: 0.2703016	total: 8.18s	remaining: 12.4s
# 398:	learn: 0.2701180	total: 8.2s	remaining: 12.4s
# 399:	learn: 0.2699542	total: 8.22s	remaining: 12.3s
# 400:	learn: 0.2699542	total: 8.24s	remaining: 12.3s
# 401:	learn: 0.2698727	total: 8.26s	remaining: 12.3s
# 402:	learn: 0.2696824	total: 8.28s	remaining: 12.3s
# 403:	learn: 0.2694077	total: 8.3s	remaining: 12.2s
# 404:	learn: 0.2688551	total: 8.32s	remaining: 12.2s
# 405:	learn: 0.2686122	total: 8.34s	remaining: 12.2s
# 406:	learn: 0.2681103	total: 8.36s	remaining: 12.2s
# 407:	learn: 0.2679238	total: 8.38s	remaining: 12.2s
# 408:	learn: 0.2677276	total: 8.39s	remaining: 12.1s
# 409:	learn: 0.2676882	total: 8.41s	remaining: 12.1s
# 410:	learn: 0.2674472	total: 8.43s	remaining: 12.1s
# 458:	learn: 0.2579064	total: 9.46s	remaining: 11.2s
# 459:	learn: 0.2577438	total: 9.48s	remaining: 11.1s
# 460:	learn: 0.2577438	total: 9.5s	remaining: 11.1s
# 461:	learn: 0.2576044	total: 9.52s	remaining: 11.1s
# 462:	learn: 0.2574653	total: 9.54s	remaining: 11.1s
# 463:	learn: 0.2572978	total: 9.56s	remaining: 11s
# 464:	learn: 0.2572922	total: 9.58s	remaining: 11s
# 465:	learn: 0.2571372	total: 9.61s	remaining: 11s
# 466:	learn: 0.2570932	total: 9.63s	remaining: 11s
# 467:	learn: 0.2564195	total: 9.65s	remaining: 11s
# 468:	learn: 0.2563647	total: 9.66s	remaining: 10.9s
# 469:	learn: 0.2561703	total: 9.68s	remaining: 10.9s
# 470:	learn: 0.2556470	total: 9.7s	remaining: 10.9s
# 471:	learn: 0.2555088	total: 9.72s	remaining: 10.9s
# 472:	learn: 0.2552675	total: 9.73s	remaining: 10.8s
# 473:	learn: 0.2549681	total: 9.75s	remaining: 10.8s
# 474:	learn: 0.2546849	total: 9.78s	remaining: 10.8s
# 475:	learn: 0.2545692	total: 9.8s	remaining: 10.8s
# 476:	learn: 0.2543902	total: 9.82s	remaining: 10.8s
# 477:	learn: 0.2543902	total: 9.84s	remaining: 10.7s
# 478:	learn: 0.2540459	total: 9.86s	remaining: 10.7s
# 479:	learn: 0.2540258	total: 9.88s	remaining: 10.7s
# 480:	learn: 0.2537574	total: 9.89s	remaining: 10.7s
# 481:	learn: 0.2536360	total: 9.91s	remaining: 10.7s
# 482:	learn: 0.2535655	total: 9.93s	remaining: 10.6s
# 483:	learn: 0.2533099	total: 9.95s	remaining: 10.6s
# 484:	learn: 0.2533062	total: 9.96s	remaining: 10.6s
# 485:	learn: 0.2532491	total: 9.98s	remaining: 10.6s
# 486:	learn: 0.2530770	total: 10s	remaining: 10.5s
# 487:	learn: 0.2530099	total: 10s	remaining: 10.5s
# 488:	learn: 0.2528461	total: 10s	remaining: 10.5s
# 489:	learn: 0.2526507	total: 10.1s	remaining: 10.5s
# 490:	learn: 0.2522323	total: 10.1s	remaining: 10.5s
# 491:	learn: 0.2521873	total: 10.1s	remaining: 10.4s
# 492:	learn: 0.2518374	total: 10.1s	remaining: 10.4s
# 493:	learn: 0.2516284	total: 10.1s	remaining: 10.4s
# 494:	learn: 0.2514961	total: 10.2s	remaining: 10.4s
# 495:	learn: 0.2512914	total: 10.2s	remaining: 10.3s
# 496:	learn: 0.2510718	total: 10.2s	remaining: 10.3s
# 497:	learn: 0.2509473	total: 10.2s	remaining: 10.3s
# 498:	learn: 0.2505216	total: 10.3s	remaining: 10.3s
# 499:	learn: 0.2503905	total: 10.3s	remaining: 10.3s
# 500:	learn: 0.2498096	total: 10.3s	remaining: 10.3s
# 501:	learn: 0.2493939	total: 10.3s	remaining: 10.2s
# 502:	learn: 0.2492847	total: 10.3s	remaining: 10.2s
# 503:	learn: 0.2488033	total: 10.3s	remaining: 10.2s
# 504:	learn: 0.2486532	total: 10.4s	remaining: 10.2s
# 645:	learn: 0.2286401	total: 13.7s	remaining: 7.5s
# 646:	learn: 0.2283925	total: 13.7s	remaining: 7.48s
# 647:	learn: 0.2283629	total: 13.7s	remaining: 7.46s
# 648:	learn: 0.2281495	total: 13.8s	remaining: 7.45s
# 649:	learn: 0.2280934	total: 13.8s	remaining: 7.42s
# 650:	learn: 0.2280601	total: 13.8s	remaining: 7.41s
# 651:	learn: 0.2279595	total: 13.8s	remaining: 7.39s
# 652:	learn: 0.2278469	total: 13.9s	remaining: 7.37s
# 653:	learn: 0.2278388	total: 13.9s	remaining: 7.35s
# 654:	learn: 0.2277233	total: 13.9s	remaining: 7.33s
# 655:	learn: 0.2274931	total: 14s	remaining: 7.32s
# 656:	learn: 0.2272551	total: 14s	remaining: 7.3s
# 657:	learn: 0.2271470	total: 14s	remaining: 7.28s
# 658:	learn: 0.2268794	total: 14s	remaining: 7.27s
# 659:	learn: 0.2267795	total: 14.1s	remaining: 7.25s
# 660:	learn: 0.2266868	total: 14.1s	remaining: 7.23s
# 661:	learn: 0.2265405	total: 14.1s	remaining: 7.21s
# 662:	learn: 0.2264306	total: 14.1s	remaining: 7.19s
# 663:	learn: 0.2262194	total: 14.2s	remaining: 7.17s
# 664:	learn: 0.2260841	total: 14.2s	remaining: 7.16s
# 665:	learn: 0.2260700	total: 14.2s	remaining: 7.14s
# 666:	learn: 0.2260148	total: 14.3s	remaining: 7.12s
# 667:	learn: 0.2259997	total: 14.3s	remaining: 7.1s
# 668:	learn: 0.2259053	total: 14.3s	remaining: 7.08s
# 669:	learn: 0.2257024	total: 14.3s	remaining: 7.06s
# 670:	learn: 0.2255926	total: 14.4s	remaining: 7.04s
# 671:	learn: 0.2254300	total: 14.4s	remaining: 7.02s
# 672:	learn: 0.2254224	total: 14.4s	remaining: 7s
# 673:	learn: 0.2252876	total: 14.4s	remaining: 6.99s
# 674:	learn: 0.2250764	total: 14.5s	remaining: 6.96s
# 675:	learn: 0.2249093	total: 14.5s	remaining: 6.95s
# 676:	learn: 0.2247761	total: 14.5s	remaining: 6.93s
# 677:	learn: 0.2245973	total: 14.6s	remaining: 6.91s
# 678:	learn: 0.2245207	total: 14.6s	remaining: 6.89s
# 679:	learn: 0.2244292	total: 14.6s	remaining: 6.87s
# 680:	learn: 0.2243085	total: 14.6s	remaining: 6.85s
# 681:	learn: 0.2241428	total: 14.7s	remaining: 6.83s
# 682:	learn: 0.2239184	total: 14.7s	remaining: 6.81s
# 683:	learn: 0.2238474	total: 14.7s	remaining: 6.79s
# 684:	learn: 0.2238395	total: 14.7s	remaining: 6.78s
# 685:	learn: 0.2237208	total: 14.8s	remaining: 6.75s
# 686:	learn: 0.2235892	total: 14.8s	remaining: 6.74s
# 687:	learn: 0.2234809	total: 14.8s	remaining: 6.72s
# 688:	learn: 0.2233486	total: 14.8s	remaining: 6.7s
# 689:	learn: 0.2231202	total: 14.9s	remaining: 6.68s
# 690:	learn: 0.2229993	total: 14.9s	remaining: 6.66s
# 691:	learn: 0.2229897	total: 14.9s	remaining: 6.64s
# 692:	learn: 0.2229867	total: 14.9s	remaining: 6.62s
# 693:	learn: 0.2229646	total: 15s	remaining: 6.6s
# 694:	learn: 0.2226237	total: 15s	remaining: 6.58s
# 695:	learn: 0.2225708	total: 15s	remaining: 6.56s
# 696:	learn: 0.2224087	total: 15.1s	remaining: 6.54s
# 697:	learn: 0.2223811	total: 15.1s	remaining: 6.52s
# 698:	learn: 0.2220562	total: 15.1s	remaining: 6.5s
# 699:	learn: 0.2219741	total: 15.1s	remaining: 6.48s
# 700:	learn: 0.2218730	total: 15.2s	remaining: 6.46s
# 701:	learn: 0.2217839	total: 15.2s	remaining: 6.44s
# 702:	learn: 0.2216422	total: 15.2s	remaining: 6.42s
# 703:	learn: 0.2214689	total: 15.2s	remaining: 6.41s
# 704:	learn: 0.2213793	total: 15.3s	remaining: 6.39s
# 705:	learn: 0.2213198	total: 15.3s	remaining: 6.37s
# 706:	learn: 0.2212302	total: 15.3s	remaining: 6.35s
# 707:	learn: 0.2210562	total: 15.3s	remaining: 6.33s
# 708:	learn: 0.2208976	total: 15.4s	remaining: 6.3s
# 709:	learn: 0.2206907	total: 15.4s	remaining: 6.29s
# 710:	learn: 0.2205693	total: 15.4s	remaining: 6.26s
# 711:	learn: 0.2204357	total: 15.4s	remaining: 6.25s
# 712:	learn: 0.2201229	total: 15.5s	remaining: 6.22s
# 713:	learn: 0.2199527	total: 15.5s	remaining: 6.2s
# 714:	learn: 0.2198172	total: 15.5s	remaining: 6.18s
# 715:	learn: 0.2197295	total: 15.5s	remaining: 6.16s
# 716:	learn: 0.2195622	total: 15.6s	remaining: 6.14s
# 717:	learn: 0.2194677	total: 15.6s	remaining: 6.12s
# 718:	learn: 0.2192685	total: 15.6s	remaining: 6.1s
# 719:	learn: 0.2191499	total: 15.6s	remaining: 6.08s
# 720:	learn: 0.2189561	total: 15.7s	remaining: 6.06s
# 721:	learn: 0.2188770	total: 15.7s	remaining: 6.04s
# 722:	learn: 0.2186924	total: 15.7s	remaining: 6.02s
# 723:	learn: 0.2185448	total: 15.7s	remaining: 6s
# 724:	learn: 0.2184201	total: 15.8s	remaining: 5.98s
# 725:	learn: 0.2182508	total: 15.8s	remaining: 5.96s
# 726:	learn: 0.2180699	total: 15.8s	remaining: 5.94s
# 727:	learn: 0.2180259	total: 15.8s	remaining: 5.92s
# 728:	learn: 0.2180068	total: 15.9s	remaining: 5.9s
# 729:	learn: 0.2178184	total: 15.9s	remaining: 5.88s
# 730:	learn: 0.2178047	total: 15.9s	remaining: 5.86s
# 731:	learn: 0.2176805	total: 15.9s	remaining: 5.84s
# 732:	learn: 0.2175084	total: 16s	remaining: 5.82s
# 733:	learn: 0.2173287	total: 16s	remaining: 5.8s
# 734:	learn: 0.2172476	total: 16s	remaining: 5.78s
# 735:	learn: 0.2172345	total: 16s	remaining: 5.75s
# 736:	learn: 0.2170414	total: 16.1s	remaining: 5.73s
# 737:	learn: 0.2169154	total: 16.1s	remaining: 5.71s
# 738:	learn: 0.2167397	total: 16.1s	remaining: 5.7s
# 739:	learn: 0.2167145	total: 16.2s	remaining: 5.68s
# 740:	learn: 0.2164753	total: 16.2s	remaining: 5.66s
# 741:	learn: 0.2162976	total: 16.2s	remaining: 5.64s
# 742:	learn: 0.2161222	total: 16.3s	remaining: 5.62s
# 743:	learn: 0.2159810	total: 16.3s	remaining: 5.6s
# 744:	learn: 0.2157764	total: 16.3s	remaining: 5.58s
# 745:	learn: 0.2157211	total: 16.3s	remaining: 5.56s
# 746:	learn: 0.2155879	total: 16.4s	remaining: 5.54s
# 747:	learn: 0.2154096	total: 16.4s	remaining: 5.52s
# 748:	learn: 0.2152367	total: 16.4s	remaining: 5.5s
# 749:	learn: 0.2151793	total: 16.4s	remaining: 5.48s
# 750:	learn: 0.2151544	total: 16.5s	remaining: 5.46s
# 751:	learn: 0.2150013	total: 16.5s	remaining: 5.44s
# 752:	learn: 0.2149615	total: 16.5s	remaining: 5.42s
# 753:	learn: 0.2149536	total: 16.6s	remaining: 5.4s
# 754:	learn: 0.2148439	total: 16.6s	remaining: 5.38s
# 755:	learn: 0.2148227	total: 16.6s	remaining: 5.36s
# 756:	learn: 0.2146138	total: 16.6s	remaining: 5.34s
# 757:	learn: 0.2145179	total: 16.7s	remaining: 5.32s
# 758:	learn: 0.2145101	total: 16.7s	remaining: 5.3s
# 759:	learn: 0.2144172	total: 16.7s	remaining: 5.28s
# 760:	learn: 0.2144140	total: 16.8s	remaining: 5.26s
# 761:	learn: 0.2143438	total: 16.8s	remaining: 5.24s
# 762:	learn: 0.2142994	total: 16.8s	remaining: 5.22s
# 763:	learn: 0.2141694	total: 16.8s	remaining: 5.2s
# 764:	learn: 0.2140935	total: 16.9s	remaining: 5.18s
# 765:	learn: 0.2140758	total: 16.9s	remaining: 5.16s
# 766:	learn: 0.2140645	total: 16.9s	remaining: 5.13s
# 767:	learn: 0.2139473	total: 16.9s	remaining: 5.12s
# 768:	learn: 0.2139353	total: 17s	remaining: 5.09s
# 769:	learn: 0.2139046	total: 17s	remaining: 5.08s
# 770:	learn: 0.2138374	total: 17s	remaining: 5.05s
# 771:	learn: 0.2138235	total: 17s	remaining: 5.04s
# 772:	learn: 0.2137702	total: 17.1s	remaining: 5.01s
# 773:	learn: 0.2136311	total: 17.1s	remaining: 4.99s
# 774:	learn: 0.2134896	total: 17.1s	remaining: 4.97s
# 775:	learn: 0.2133068	total: 17.2s	remaining: 4.97s
# 776:	learn: 0.2132796	total: 17.2s	remaining: 4.95s
# 777:	learn: 0.2132539	total: 17.3s	remaining: 4.93s
# 778:	learn: 0.2130864	total: 17.3s	remaining: 4.91s
# 779:	learn: 0.2129386	total: 17.3s	remaining: 4.89s
# 780:	learn: 0.2127977	total: 17.3s	remaining: 4.86s
# 781:	learn: 0.2126095	total: 17.4s	remaining: 4.84s
# 782:	learn: 0.2125372	total: 17.4s	remaining: 4.82s
# 783:	learn: 0.2123759	total: 17.4s	remaining: 4.8s
# 784:	learn: 0.2123112	total: 17.5s	remaining: 4.79s
# 785:	learn: 0.2122620	total: 17.5s	remaining: 4.77s
# 786:	learn: 0.2122572	total: 17.5s	remaining: 4.75s
# 787:	learn: 0.2121051	total: 17.6s	remaining: 4.73s
# 788:	learn: 0.2120918	total: 17.6s	remaining: 4.7s
# 789:	learn: 0.2119400	total: 17.6s	remaining: 4.68s
# 790:	learn: 0.2118748	total: 17.6s	remaining: 4.66s
# 791:	learn: 0.2117966	total: 17.7s	remaining: 4.64s
# 792:	learn: 0.2116819	total: 17.7s	remaining: 4.62s
# 793:	learn: 0.2115944	total: 17.7s	remaining: 4.6s
# 794:	learn: 0.2115726	total: 17.8s	remaining: 4.58s
# 795:	learn: 0.2115613	total: 17.8s	remaining: 4.56s
# 796:	learn: 0.2115039	total: 17.8s	remaining: 4.54s
# 797:	learn: 0.2113783	total: 17.8s	remaining: 4.52s
# 798:	learn: 0.2111693	total: 17.9s	remaining: 4.5s
# 799:	learn: 0.2111106	total: 17.9s	remaining: 4.48s
# 800:	learn: 0.2110202	total: 17.9s	remaining: 4.46s
# 801:	learn: 0.2109760	total: 18s	remaining: 4.44s
# 802:	learn: 0.2108986	total: 18s	remaining: 4.42s
# 803:	learn: 0.2108270	total: 18s	remaining: 4.39s
# 804:	learn: 0.2108145	total: 18s	remaining: 4.37s
# 805:	learn: 0.2107624	total: 18.1s	remaining: 4.35s
# 806:	learn: 0.2107449	total: 18.1s	remaining: 4.33s
# 807:	learn: 0.2105837	total: 18.1s	remaining: 4.31s
# 808:	learn: 0.2104308	total: 18.2s	remaining: 4.29s
# 809:	learn: 0.2104166	total: 18.2s	remaining: 4.26s
# 810:	learn: 0.2103752	total: 18.2s	remaining: 4.25s
# 811:	learn: 0.2102485	total: 18.2s	remaining: 4.22s
# 812:	learn: 0.2101232	total: 18.3s	remaining: 4.2s
# 813:	learn: 0.2099833	total: 18.3s	remaining: 4.18s
# 814:	learn: 0.2098211	total: 18.3s	remaining: 4.16s
# 815:	learn: 0.2097613	total: 18.3s	remaining: 4.14s
# 816:	learn: 0.2097237	total: 18.4s	remaining: 4.12s
# 817:	learn: 0.2096822	total: 18.4s	remaining: 4.09s
# 818:	learn: 0.2096102	total: 18.4s	remaining: 4.07s
# 819:	learn: 0.2095852	total: 18.5s	remaining: 4.05s
# 820:	learn: 0.2095747	total: 18.5s	remaining: 4.03s
# 821:	learn: 0.2095255	total: 18.5s	remaining: 4.01s
# 822:	learn: 0.2092964	total: 18.5s	remaining: 3.98s
# 823:	learn: 0.2091607	total: 18.6s	remaining: 3.96s
# 824:	learn: 0.2090848	total: 18.6s	remaining: 3.94s
# 825:	learn: 0.2089929	total: 18.6s	remaining: 3.92s
# 826:	learn: 0.2088228	total: 18.6s	remaining: 3.9s
# 827:	learn: 0.2087169	total: 18.7s	remaining: 3.88s
# 828:	learn: 0.2086587	total: 18.7s	remaining: 3.86s
# 829:	learn: 0.2086043	total: 18.7s	remaining: 3.83s
# 830:	learn: 0.2084307	total: 18.7s	remaining: 3.81s
# 831:	learn: 0.2083440	total: 18.8s	remaining: 3.79s
# 832:	learn: 0.2081543	total: 18.8s	remaining: 3.77s
# 833:	learn: 0.2080967	total: 18.8s	remaining: 3.75s
# 834:	learn: 0.2080359	total: 18.9s	remaining: 3.73s
# 835:	learn: 0.2079751	total: 18.9s	remaining: 3.7s
# 836:	learn: 0.2077688	total: 18.9s	remaining: 3.68s
# 837:	learn: 0.2076298	total: 18.9s	remaining: 3.66s
# 838:	learn: 0.2075590	total: 19s	remaining: 3.64s
# 839:	learn: 0.2074995	total: 19s	remaining: 3.62s
# 840:	learn: 0.2074878	total: 19s	remaining: 3.59s
# 841:	learn: 0.2074461	total: 19s	remaining: 3.57s
# 842:	learn: 0.2074096	total: 19.1s	remaining: 3.55s
# 843:	learn: 0.2073988	total: 19.1s	remaining: 3.53s
# 844:	learn: 0.2073526	total: 19.1s	remaining: 3.5s
# 845:	learn: 0.2071785	total: 19.1s	remaining: 3.48s
# 846:	learn: 0.2070607	total: 19.2s	remaining: 3.46s
# 847:	learn: 0.2069397	total: 19.2s	remaining: 3.44s
# 848:	learn: 0.2068234	total: 19.3s	remaining: 3.43s
# 849:	learn: 0.2066680	total: 19.3s	remaining: 3.41s
# 850:	learn: 0.2065637	total: 19.4s	remaining: 3.39s
# 851:	learn: 0.2065310	total: 19.4s	remaining: 3.37s
# 852:	learn: 0.2063186	total: 19.4s	remaining: 3.35s
# 853:	learn: 0.2062215	total: 19.5s	remaining: 3.33s
# 854:	learn: 0.2062064	total: 19.5s	remaining: 3.3s
# 855:	learn: 0.2060883	total: 19.5s	remaining: 3.28s
# 856:	learn: 0.2060327	total: 19.5s	remaining: 3.26s
# 857:	learn: 0.2059080	total: 19.6s	remaining: 3.24s
# 858:	learn: 0.2057885	total: 19.6s	remaining: 3.21s
# 859:	learn: 0.2057029	total: 19.6s	remaining: 3.19s
# 860:	learn: 0.2056519	total: 19.6s	remaining: 3.17s
# 861:	learn: 0.2056074	total: 19.7s	remaining: 3.15s
# 862:	learn: 0.2055622	total: 19.7s	remaining: 3.13s
# 863:	learn: 0.2055084	total: 19.7s	remaining: 3.1s
# 864:	learn: 0.2054079	total: 19.7s	remaining: 3.08s
# 865:	learn: 0.2053078	total: 19.8s	remaining: 3.06s
# 866:	learn: 0.2051761	total: 19.8s	remaining: 3.04s
# 867:	learn: 0.2051489	total: 19.8s	remaining: 3.01s
# 868:	learn: 0.2050087	total: 19.9s	remaining: 2.99s
# 869:	learn: 0.2049416	total: 19.9s	remaining: 2.97s
# 870:	learn: 0.2048132	total: 19.9s	remaining: 2.95s
# 871:	learn: 0.2046953	total: 19.9s	remaining: 2.93s
# 872:	learn: 0.2045001	total: 20s	remaining: 2.9s
# 873:	learn: 0.2043522	total: 20s	remaining: 2.88s
# 874:	learn: 0.2042936	total: 20s	remaining: 2.86s
# 875:	learn: 0.2040816	total: 20s	remaining: 2.84s
# 876:	learn: 0.2040389	total: 20.1s	remaining: 2.82s
# 877:	learn: 0.2039562	total: 20.1s	remaining: 2.79s
# 878:	learn: 0.2038474	total: 20.1s	remaining: 2.77s
# 879:	learn: 0.2037770	total: 20.2s	remaining: 2.75s
# 880:	learn: 0.2037310	total: 20.2s	remaining: 2.73s
# 881:	learn: 0.2036837	total: 20.2s	remaining: 2.71s
# 882:	learn: 0.2035453	total: 20.2s	remaining: 2.68s
# 883:	learn: 0.2034843	total: 20.3s	remaining: 2.66s
# 884:	learn: 0.2033684	total: 20.3s	remaining: 2.64s
# 885:	learn: 0.2032309	total: 20.3s	remaining: 2.62s
# 886:	learn: 0.2031644	total: 20.4s	remaining: 2.59s
# 887:	learn: 0.2031223	total: 20.4s	remaining: 2.57s
# 888:	learn: 0.2029882	total: 20.4s	remaining: 2.55s
# 889:	learn: 0.2028665	total: 20.5s	remaining: 2.53s
# 890:	learn: 0.2027737	total: 20.5s	remaining: 2.5s
# 891:	learn: 0.2026106	total: 20.5s	remaining: 2.48s
# 892:	learn: 0.2025598	total: 20.5s	remaining: 2.46s
# 893:	learn: 0.2023353	total: 20.6s	remaining: 2.44s
# 894:	learn: 0.2022941	total: 20.6s	remaining: 2.42s
# 895:	learn: 0.2022554	total: 20.6s	remaining: 2.39s
# 896:	learn: 0.2021364	total: 20.6s	remaining: 2.37s
# 897:	learn: 0.2019054	total: 20.7s	remaining: 2.35s
# 898:	learn: 0.2017828	total: 20.7s	remaining: 2.32s
# 899:	learn: 0.2017207	total: 20.7s	remaining: 2.3s
# 900:	learn: 0.2016549	total: 20.7s	remaining: 2.28s
# 901:	learn: 0.2016082	total: 20.8s	remaining: 2.26s
# 902:	learn: 0.2015978	total: 20.8s	remaining: 2.23s
# 903:	learn: 0.2015236	total: 20.8s	remaining: 2.21s
# 904:	learn: 0.2014303	total: 20.9s	remaining: 2.19s
# 905:	learn: 0.2014240	total: 20.9s	remaining: 2.17s
# 906:	learn: 0.2013711	total: 20.9s	remaining: 2.15s
# 907:	learn: 0.2013128	total: 21s	remaining: 2.12s
# 908:	learn: 0.2011552	total: 21s	remaining: 2.1s
# 909:	learn: 0.2010596	total: 21s	remaining: 2.08s
# 910:	learn: 0.2008806	total: 21s	remaining: 2.06s
# 911:	learn: 0.2008412	total: 21.1s	remaining: 2.03s
# 912:	learn: 0.2007170	total: 21.1s	remaining: 2.01s
# 913:	learn: 0.2006213	total: 21.1s	remaining: 1.99s
# 914:	learn: 0.2004529	total: 21.1s	remaining: 1.96s
# 915:	learn: 0.2002107	total: 21.2s	remaining: 1.94s
# 916:	learn: 0.2001706	total: 21.2s	remaining: 1.92s
# 917:	learn: 0.2001369	total: 21.2s	remaining: 1.9s
# 918:	learn: 0.2000973	total: 21.3s	remaining: 1.87s
# 919:	learn: 0.1999108	total: 21.3s	remaining: 1.85s
# 920:	learn: 0.1998093	total: 21.3s	remaining: 1.83s
# 921:	learn: 0.1997099	total: 21.3s	remaining: 1.8s
# 922:	learn: 0.1996290	total: 21.4s	remaining: 1.78s
# 923:	learn: 0.1994979	total: 21.4s	remaining: 1.76s
# 924:	learn: 0.1994266	total: 21.4s	remaining: 1.74s
# 925:	learn: 0.1993885	total: 21.5s	remaining: 1.71s
# 926:	learn: 0.1992921	total: 21.5s	remaining: 1.69s
# 974:	learn: 0.1955659	total: 22.8s	remaining: 585ms
# 975:	learn: 0.1955432	total: 22.8s	remaining: 562ms
# 976:	learn: 0.1954942	total: 22.9s	remaining: 539ms
# 977:	learn: 0.1954744	total: 22.9s	remaining: 515ms
# 978:	learn: 0.1954035	total: 22.9s	remaining: 492ms
# 979:	learn: 0.1953572	total: 23s	remaining: 469ms
# 980:	learn: 0.1952520	total: 23s	remaining: 445ms
# 981:	learn: 0.1951188	total: 23s	remaining: 422ms
# 982:	learn: 0.1949677	total: 23s	remaining: 398ms
# 983:	learn: 0.1948651	total: 23.1s	remaining: 375ms
# 984:	learn: 0.1948326	total: 23.1s	remaining: 352ms
# 985:	learn: 0.1948250	total: 23.1s	remaining: 328ms
# 986:	learn: 0.1947845	total: 23.1s	remaining: 305ms
# 987:	learn: 0.1947584	total: 23.2s	remaining: 281ms
# 988:	learn: 0.1947144	total: 23.2s	remaining: 258ms
# 989:	learn: 0.1947063	total: 23.2s	remaining: 234ms
# 990:	learn: 0.1946582	total: 23.2s	remaining: 211ms
# 991:	learn: 0.1945386	total: 23.2s	remaining: 187ms
# 992:	learn: 0.1945027	total: 23.3s	remaining: 164ms
# 993:	learn: 0.1944358	total: 23.3s	remaining: 141ms
# 994:	learn: 0.1943351	total: 23.3s	remaining: 117ms
# 995:	learn: 0.1943310	total: 23.3s	remaining: 93.7ms
# 996:	learn: 0.1943089	total: 23.4s	remaining: 70.3ms
# 997:	learn: 0.1941667	total: 23.4s	remaining: 46.9ms
# 998:	learn: 0.1940637	total: 23.4s	remaining: 23.4ms
# 999:	learn: 0.1940499	total: 23.4s	remaining: 0us
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89       903
#            1       0.88      0.91      0.90       925
#
#     accuracy                           0.89      1828
#    macro avg       0.89      0.89      0.89      1828
# weighted avg       0.89      0.89      0.89      1828

# %%
# Printing the default parameters
print(model_cb.get_params())
# Out:
# {'cat_features': ['V013', 'V024', 'V025', 'V106', 'V701', 'V201', 'V122', 'V159', 'V704', 'V190', 'V161', 'V404']}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_cb = accuracy_score(y_test, y_pred)
precision_cb = precision_score(y_test, y_pred)
recall_cb = recall_score(y_test, y_pred)
f1_cb = f1_score(y_test, y_pred)
kappa_cb = cohen_kappa_score(y_test, y_pred)
specificity_cb = specificity_score(y_test, y_pred)
log_loss_cb = log_loss(y_test, y_pred)
roc_auc_score_cb = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_cb)
print("Precision:", precision_cb)
print("Recall:", recall_cb)
print("F1 Score:", f1_cb)
print("Kappa:", kappa_cb)
print("Specificity:", specificity_cb)
print("AUC:", roc_auc_score_cb)
print("Log Loss:", log_loss_cb)
# Out:
# Accuracy: 0.8933260393873085
# Precision: 0.8802083333333334
# Recall: 0.9135135135135135
# F1 Score: 0.896551724137931
# Kappa: 0.7865227754554492
# Specificity: 0.8726467331118494
# AUC: 0.8930801233126815
# Log Loss: 3.8449192619681867

# %% [markdown]
# ### 7. Multi-Layer Perceptron (MLP)

# %%
# Initialize the MLP model
model_mlp=MLPClassifier()
model_mlp.fit(x_train, y_train) 
y_pred = model_mlp.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84       903
#            1       0.84      0.85      0.85       925
#
#     accuracy                           0.84      1828
#    macro avg       0.84      0.84      0.84      1828
# weighted avg       0.84      0.84      0.84      1828

# %%
# Printing the default parameters
print(model_mlp.get_params())
# Out:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': None, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_mlp = accuracy_score(y_test, y_pred)
precision_mlp = precision_score(y_test, y_pred)
recall_mlp = recall_score(y_test, y_pred)
f1_mlp = f1_score(y_test, y_pred)
kappa_mlp = cohen_kappa_score(y_test, y_pred)
specificity_mlp = specificity_score(y_test, y_pred)
log_loss_mlp = log_loss(y_test, y_pred)
roc_auc_score_mlp = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_mlp)
print("Precision:", precision_mlp)
print("Recall:", recall_mlp)
print("F1 Score:", f1_mlp)
print("Kappa:", kappa_mlp)
print("Specificity:", specificity_mlp)
print("AUC:", roc_auc_score_mlp)
print("Log Loss:", log_loss_mlp)
# Out:
# Accuracy: 0.8424507658643327
# Precision: 0.8406417112299466
# Recall: 0.8497297297297297
# F1 Score: 0.8451612903225807
# Kappa: 0.6848143779971623
# Specificity: 0.8349944629014396
# AUC: 0.8423620963155847
# Log Loss: 5.678649986906859

# %% [markdown]
# ## Hyperparameter Tuned Classification Algorithm

# %% [markdown]
# ### 1. Support Vector Machine (SVM)

# %%
# Optimize the parameter grid for hyperparameter tuning
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
			'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
			'kernel': ['rbf','linear'],
            } 
model_svm=SVC()
# Set up the GridSearchCV to find the best combination of parameters
grid_search_svm= GridSearchCV(estimator=model_svm, param_grid=param_grid,refit = True, cv=5, n_jobs=-1, verbose=3) 
grid_search_svm.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf', 'linear']},
#              verbose=3)

# %%
# Printing the  parameters
print(grid_search_svm.best_params_) 
print(grid_search_svm.best_estimator_)
# Out:
# {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# SVC(C=10, gamma=1)

# %%
# Print the classification report
y_pred_svm = grid_search_svm.predict(x_test) 
print(classification_report(y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       903
#            1       0.97      0.94      0.96       925
#
#     accuracy                           0.96      1828
#    macro avg       0.96      0.96      0.96      1828
# weighted avg       0.96      0.96      0.96      1828

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_svm = confusion_matrix(y_test, y_pred_svm)
sns.heatmap(confusion_matrix_svm,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_svm):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_svm)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_svm= accuracy_score(y_test, y_pred_svm)
precision_svm = precision_score(y_test, y_pred_svm)
recall_svm = recall_score(y_test, y_pred_svm)
f1_svm = f1_score(y_test, y_pred_svm)
kappa_svm = cohen_kappa_score(y_test, y_pred_svm)
specificity_svm = specificity_score(y_test, y_pred_svm)
log_loss_svm = log_loss(y_test, y_pred_svm)
roc_auc_score_svm = roc_auc_score(y_test, y_pred_svm)

print("Accuracy:", accuracy_svm)
print("Precision:", precision_svm)
print("Recall:", recall_svm)
print("F1 Score:", f1_svm)
print("Kappa:",kappa_svm)
print("Specificity:", specificity_svm)
print("AUC:", roc_auc_score_svm)
print("Log Loss:", log_loss_svm)
# Out:
# Accuracy: 0.9578774617067833
# Precision: 0.9732142857142857
# Recall: 0.9427027027027027
# F1 Score: 0.9577155409115871
# Kappa: 0.9157748858895588
# Specificity: 0.973421926910299
# AUC: 0.958062314806501
# Log Loss: 1.5182501701105147

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_svm, tpr_svm, _ = roc_curve(y_test, y_pred_svm)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_svm = roc_auc_score(y_test, y_pred_svm)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_svm, tpr_svm, color='darkorange', lw=2, label=f'ROC curve (area = {auc_svm:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(SVM)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# #### Feature Importance

# %%
# Compute permutation importance
perm_importance= permutation_importance(grid_search_svm, x_test, y_test, n_repeats=30, random_state=42)
importance_df = pd.DataFrame(perm_importance.importances_mean, index=x_resampled.columns, columns=["Importance"])
importance_df = importance_df.sort_values(by="Importance", ascending=False)
# Display the results
print(importance_df)
# Out:
#       Importance
# V190    0.238877
# V013    0.185248
# V024    0.174362
# V701    0.137673
# V159    0.124307
# V201    0.098377
# V704    0.097174
# V106    0.094238
# V025    0.027261
# V122    0.019967
# V404    0.017670
# V161    0.010959

# %% [markdown]
# ### 2. Logistic Regression (LR)

# %%
# Optimize the parameter grid for hyperparameter tuning
param_grid={
"penalty" : ["l1","elasticnet"],
"solver" : ["lbfgs","liblinear","sag","saga"],
"max_iter" : [100,300,500,1000],
'C':np.linspace(0,1,30)
}
model_lr = LogisticRegression(random_state= 42)
# Set up the GridSearchCV to find the best combination of parameters
grid_search_lr = GridSearchCV(estimator= model_lr, param_grid= param_grid, cv=5, scoring= 'accuracy', n_jobs=-1, verbose=1)
grid_search_lr.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 960 candidates, totalling 4800 fits
# GridSearchCV(cv=5, estimator=LogisticRegression(random_state=42), n_jobs=-1,
#              param_grid={'C': array([0.        , 0.03448276, 0.06896552, 0.10344828, 0.13793103,
#        0.17241379, 0.20689655, 0.24137931, 0.27586207, 0.31034483,
#        0.34482759, 0.37931034, 0.4137931 , 0.44827586, 0.48275862,
#        0.51724138, 0.55172414, 0.5862069 , 0.62068966, 0.65517241,
#        0.68965517, 0.72413793, 0.75862069, 0.79310345, 0.82758621,
#        0.86206897, 0.89655172, 0.93103448, 0.96551724, 1.        ]),
#                          'max_iter': [100, 300, 500, 1000],
#                          'penalty': ['l1', 'elasticnet'],
#                          'solver': ['lbfgs', 'liblinear', 'sag', 'saga']},
#              scoring='accuracy', verbose=1)

# %%
# Printing the best parameters and estimators
print(grid_search_lr.best_params_) 
print(grid_search_lr.best_estimator_)
# Out:
# {'C': 0.1724137931034483, 'max_iter': 100, 'penalty': 'l1', 'solver': 'saga'}
# LogisticRegression(C=0.1724137931034483, penalty='l1', random_state=42,
#                    solver='saga')

# %%
# Print the classification report
y_pred_lr = grid_search_lr.predict(x_test) 
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       903
#            1       0.81      0.79      0.80       925
#
#     accuracy                           0.80      1828
#    macro avg       0.80      0.80      0.80      1828
# weighted avg       0.80      0.80      0.80      1828

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_lr = confusion_matrix(y_test, y_pred_lr)
sns.heatmap(confusion_matrix_lr,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_lr):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_lr)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_lr= accuracy_score(y_test, y_pred_lr)
precision_lr = precision_score(y_test, y_pred_lr)
recall_lr = recall_score(y_test, y_pred_lr)
f1_lr = f1_score(y_test, y_pred_lr)
kappa_lr = cohen_kappa_score(y_test, y_pred_lr)
specificity_lr = specificity_score(y_test, y_pred_lr)
log_loss_lr = log_loss(y_test, y_pred_lr)
roc_auc_score_lr = roc_auc_score(y_test, y_pred_lr)

print("Accuracy:", accuracy_lr)
print("Precision:", precision_lr)
print("Recall:", recall_lr)
print("F1 Score:", f1_lr)
print("Kappa:", kappa_lr)
print("Specificity:", specificity_lr)
print("AUC:", roc_auc_score_lr)
print("Log Loss:", log_loss_lr)
# Out:
# Accuracy: 0.799781181619256
# Precision: 0.8081587651598677
# Recall: 0.7924324324324324
# F1 Score: 0.8002183406113537
# Kappa: 0.5995992689171283
# Specificity: 0.8073089700996677
# AUC: 0.79987070126605
# Log Loss: 7.216617691694135

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_lr, tpr_lr, _ = roc_curve(y_test, y_pred_lr)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_lr = roc_auc_score(y_test, y_pred_lr)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_lr, tpr_lr, color='darkorange', lw=2, label=f'ROC curve (area = {auc_lr:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(LR)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### 3. Random Forest (RF)

# %%
# Optimize the parameter grid for hyperparameter tuning
param_grid = { 
	'n_estimators': [25, 50, 100, 150], 
	'max_features': ['sqrt', 'log2'], 
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False],  
    'criterion': ['gini', 'entropy']  
}
model_rf = RandomForestClassifier(random_state=42)
# Set up the GridSearchCV to find the best combination of parameters
grid_search_rf = GridSearchCV(estimator= model_rf, param_grid= param_grid, refit=True, cv=5, verbose=True, n_jobs=-1,scoring='accuracy')
grid_search_rf.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [25, 50, 100, 150]},
#              scoring='accuracy', verbose=True)

# %%
# Printing the best parameters and estimators
print(grid_search_rf.best_params_) 
print(grid_search_rf.best_estimator_)
# Out:
# {'bootstrap': False, 'criterion': 'gini', 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# RandomForestClassifier(bootstrap=False, random_state=42)

# %%
# Print the classification report
y_pred_rf = grid_search_rf.predict(x_test) 
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       903
#            1       0.94      0.96      0.95       925
#
#     accuracy                           0.95      1828
#    macro avg       0.95      0.95      0.95      1828
# weighted avg       0.95      0.95      0.95      1828

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_rf = confusion_matrix(y_test, y_pred_rf)
sns.heatmap(confusion_matrix_rf,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_rf):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_rf)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_rf= accuracy_score(y_test, y_pred_rf)
precision_rf = precision_score(y_test, y_pred_rf)
recall_rf = recall_score(y_test, y_pred_rf)
f1_rf = f1_score(y_test, y_pred_rf)
kappa_rf = cohen_kappa_score(y_test, y_pred_rf)
specificity_rf = specificity_score(y_test, y_pred_rf)
log_loss_rf = log_loss(y_test, y_pred_rf)
roc_auc_score_rf = roc_auc_score(y_test, y_pred_rf)

print("Accuracy:", accuracy_rf)
print("Precision:", precision_rf)
print("Recall:", recall_rf)
print("F1 Score:", f1_rf)
print("Kappa:", kappa_rf)
print("Specificity:", specificity_rf)
print("AUC:", roc_auc_score_rf)
print("Log Loss:", log_loss_rf)
# Out:
# Accuracy: 0.950218818380744
# Precision: 0.9417372881355932
# Recall: 0.961081081081081
# F1 Score: 0.951310861423221
# Kappa: 0.9003982918715407
# Specificity: 0.9390919158361019
# AUC: 0.9500864984585915
# Log Loss: 1.794295655585154

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_rf, tpr_rf, _ = roc_curve(y_test, y_pred_rf)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_rf = roc_auc_score(y_test, y_pred_rf)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_rf, tpr_rf, color='darkorange', lw=2, label=f'ROC curve (area = {auc_rf:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(RF)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### 4. K-Nearest Neighbor (KNN)

# %%
# Optimize the parameter grid for hyperparameter tuning
param_grid = {
    "n_neighbors" : [3,4,5,8,10],
    'metric': ['euclidean', 'manhattan'],
    "weights" : ["uniform","distance"],
    "algorithm" : ["auto","ball_tree","kd_tree","brute"],
    "leaf_size" : [10,20,30,40,50],
}
model_knn = KNeighborsClassifier()
# Set up the GridSearchCV to find the best combination of parameters
grid_search_knn= GridSearchCV(estimator= model_knn, param_grid= param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search_knn.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 400 candidates, totalling 2000 fits
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'leaf_size': [10, 20, 30, 40, 50],
#                          'metric': ['euclidean', 'manhattan'],
#                          'n_neighbors': [3, 4, 5, 8, 10],
#                          'weights': ['uniform', 'distance']},
#              verbose=2)

# %%
# Printing the best parameters and estimators
print(grid_search_knn.best_params_) 
print(grid_search_knn.best_estimator_)
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# KNeighborsClassifier(metric='manhattan', n_neighbors=4, weights='distance')

# %%
# Print the classification report
y_pred_knn = grid_search_knn.predict(x_test) 
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       903
#            1       0.94      0.97      0.95       925
#
#     accuracy                           0.95      1828
#    macro avg       0.95      0.95      0.95      1828
# weighted avg       0.95      0.95      0.95      1828

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_knn = confusion_matrix(y_test, y_pred_knn)
sns.heatmap(confusion_matrix_knn,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_knn):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_knn)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_knn= accuracy_score(y_test, y_pred_knn)
precision_knn = precision_score(y_test, y_pred_knn)
recall_knn = recall_score(y_test, y_pred_knn)
f1_knn = f1_score(y_test, y_pred_knn)
kappa_knn = cohen_kappa_score(y_test, y_pred_knn)
specificity_knn = specificity_score(y_test, y_pred_knn)
log_loss_knn = log_loss(y_test, y_pred_knn)
roc_auc_score_knn = roc_auc_score(y_test, y_pred_knn)

print("Accuracy:", accuracy_knn)
print("Precision:", precision_knn)
print("Recall:", recall_knn)
print("F1 Score:", f1_knn)
print("Kappa:", kappa_knn)
print("Specificity:", specificity_knn)
print("AUC:", roc_auc_score_knn)
print("Log Loss:", log_loss_knn)
# Out:
# Accuracy: 0.9513129102844639
# Precision: 0.9390756302521008
# Recall: 0.9664864864864865
# F1 Score: 0.9525839104954715
# Kappa: 0.9025770738869767
# Specificity: 0.9357696566998892
# AUC: 0.9511280715931877
# Log Loss: 1.7548605862316335

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_knn, tpr_knn, _ = roc_curve(y_test, y_pred_knn)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_knn = roc_auc_score(y_test, y_pred_knn)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_knn, tpr_knn, color='darkorange', lw=2, label=f'ROC curve (area = {auc_knn:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(KNN)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### 5. Extreme Gradient Boosting (XGBoost)

# %%
# Optimize the parameter grid for hyperparameter tuning
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 4, 5, 6],
    'min_child_weight': [1, 2, 3],
    'subsample': [0.6, 0.7, 0.8, 0.9],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9],
    'gamma': [0, 0.1, 0.2]
}
model_xgb = xgb.XGBClassifier(enable_categorical=True, random_state=42)
# Set up the GridSearchCV to find the best combination of parameters
grid_search_xgb = GridSearchCV(estimator= model_xgb, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search_xgb.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 5184 candidates, totalling 25920 fits
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=True, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, m...
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=42, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.6, 0.7, 0.8, 0.9],
#                          'gamma': [0, 0.1, 0.2],
#                          'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 4, 5, 6],
#                          'min_child_weight': [1, 2, 3],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.6, 0.7, 0.8, 0.9]},
#              verbose=2)

# %%
# Printing the best parameters and estimators
print(grid_search_xgb.best_params_) 
print(grid_search_xgb.best_estimator_)
# Out:
# {'colsample_bytree': 0.9, 'gamma': 0, 'learning_rate': 0.2, 'max_depth': 6, 'min_child_weight': 1, 'n_estimators': 300, 'subsample': 0.8}
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               gamma=0, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
# Print the classification report
y_pred_xgb = grid_search_xgb.predict(x_test) 
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       903
#            1       0.94      0.96      0.95       925
#
#     accuracy                           0.95      1828
#    macro avg       0.95      0.95      0.95      1828
# weighted avg       0.95      0.95      0.95      1828

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_xgb = confusion_matrix(y_test, y_pred_xgb)
sns.heatmap(confusion_matrix_xgb,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_xgb):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_xgb)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_xgb= accuracy_score(y_test, y_pred_xgb)
precision_xgb = precision_score(y_test, y_pred_xgb)
recall_xgb = recall_score(y_test, y_pred_xgb)
f1_xgb = f1_score(y_test, y_pred_xgb)
kappa_xgb = cohen_kappa_score(y_test, y_pred_xgb)
specificity_xgb = specificity_score(y_test, y_pred_xgb)
log_loss_xgb = log_loss(y_test, y_pred_xgb)
roc_auc_score_xgb = roc_auc_score(y_test, y_pred_xgb)

print("Accuracy:", accuracy_xgb)
print("Precision:", precision_xgb)
print("Recall:", recall_xgb)
print("F1 Score:", f1_xgb)
print("Kappa:", kappa_xgb)
print("Specificity:", specificity_xgb)
print("AUC:", roc_auc_score_xgb)
print("Log Loss:", log_loss_xgb)
# Out:
# Accuracy: 0.9452954048140044
# Precision: 0.9365079365079365
# Recall: 0.9567567567567568
# F1 Score: 0.946524064171123
# Kappa: 0.8905461316919245
# Specificity: 0.9335548172757475
# AUC: 0.9451557870162521
# Log Loss: 1.9717534676759931

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_xgb, tpr_xgb, _ = roc_curve(y_test, y_pred_xgb)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_xgb = roc_auc_score(y_test, y_pred_xgb)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_xgb, tpr_xgb, color='darkorange', lw=2, label=f'ROC curve (area = {auc_xgb:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(XGBoost)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### 6. Categorical Boosting (CatBoost)

# %%
cat_features = ['V013', 'V024', 'V025', 'V106', 'V701', 'V201', 'V122', 'V159', 'V704', 'V190', 'V161', 'V404']
model_cb = CatBoostClassifier(random_state=42, verbose=False,cat_features = cat_features )
# Optimize the parameter grid for hyperparameter tuning
param_grid = {
    'depth': [4, 6, 8],
    'learning_rate': [0.01, 0.05, 0.1],
    'iterations': [100, 200, 300],
    'l2_leaf_reg': [1, 3, 5, 7, 9]
}
# Set up the GridSearchCV to find the best combination of parameters
grid_search_cb = GridSearchCV(estimator= model_cb, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search_cb.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# GridSearchCV(cv=5,
#              estimator=<catboost.core.CatBoostClassifier object at 0x000002588746FBF0>,
#              n_jobs=-1,
#              param_grid={'depth': [4, 6, 8], 'iterations': [100, 200, 300],
#                          'l2_leaf_reg': [1, 3, 5, 7, 9],
#                          'learning_rate': [0.01, 0.05, 0.1]},
#              verbose=2)

# %%
# Printing the best parameters and estimators
print(grid_search_cb.best_params_) 
print(grid_search_cb.best_estimator_)
# Out:
# {'depth': 8, 'iterations': 300, 'l2_leaf_reg': 3, 'learning_rate': 0.1}
# <catboost.core.CatBoostClassifier object at 0x000002588753FD10>

# %%
# Print the classification report
y_pred_cb = grid_search_cb.predict(x_test) 
print(classification_report(y_test, y_pred_cb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       903
#            1       0.90      0.94      0.92       925
#
#     accuracy                           0.92      1828
#    macro avg       0.92      0.92      0.92      1828
# weighted avg       0.92      0.92      0.92      1828

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_cb = confusion_matrix(y_test, y_pred_cb)
sns.heatmap(confusion_matrix_cb,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_cb):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_cb)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_cb = accuracy_score(y_test, y_pred_cb)
precision_cb = precision_score(y_test, y_pred_cb)
recall_cb = recall_score(y_test, y_pred_cb)
f1_cb = f1_score(y_test, y_pred_cb)
kappa_cb = cohen_kappa_score(y_test, y_pred_cb)
specificity_cb = specificity_score(y_test, y_pred_cb)
log_loss_cb = log_loss(y_test, y_pred_cb)
roc_auc_score_cb = roc_auc_score(y_test, y_pred_cb)

print("Accuracy:", accuracy_cb)
print("Precision:", precision_cb)
print("Recall:", recall_cb)
print("F1 Score:", f1_cb)
print("Kappa:", kappa_cb)
print("Specificity:", specificity_cb)
print("AUC:", roc_auc_score_cb)
print("Log Loss:", log_loss_cb)
# Out:
# Accuracy: 0.9157549234135668
# Precision: 0.9011446409989594
# Recall: 0.9362162162162162
# F1 Score: 0.9183457051961824
# Kappa: 0.8314055090617922
# Specificity: 0.8947951273532669
# AUC: 0.9155056717847415
# Log Loss: 3.0365003402210293

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_cb, tpr_cb, _ = roc_curve(y_test, y_pred_cb)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_cb = roc_auc_score(y_test, y_pred_cb)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_cb, tpr_cb, color='darkorange', lw=2, label=f'ROC curve (area = {auc_cb:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(CatBoost)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### 7. Multi-Layer Perceptron (MLP)

# %%
# Optimize the parameter grid for hyperparameter tuning
param_grid= {
   'hidden_layer_sizes': [(50,), (50,50), (100,),(100,50)],
    'activation': ['tanh', 'relu','logistic'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001,0.001,.01, 0.05],
    'learning_rate': ['constant','adaptive','invscaling'],
}
model_mlp=MLPClassifier(random_state=42)
# Set up the GridSearchCV to find the best combination of parameters
grid_search_mlp= GridSearchCV( estimator= model_mlp, param_grid=param_grid, cv = 5, n_jobs=-1, verbose=2)
grid_search_mlp.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# GridSearchCV(cv=5, estimator=MLPClassifier(random_state=42), n_jobs=-1,
#              param_grid={'activation': ['tanh', 'relu', 'logistic'],
#                          'alpha': [0.0001, 0.001, 0.01, 0.05],
#                          'hidden_layer_sizes': [(50,), (50, 50), (100,),
#                                                 (100, 50)],
#                          'learning_rate': ['constant', 'adaptive',
#                                            'invscaling'],
#                          'solver': ['sgd', 'adam']},
#              verbose=2)

# %%
# Printing the best parameters and estimators
print(grid_search_mlp.best_params_) 
print(grid_search_mlp.best_estimator_)
# Out:
# {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# MLPClassifier(hidden_layer_sizes=(100, 50), random_state=42)

# %%
# Print the classification report
y_pred_mlp = grid_search_mlp.predict(x_test) 
print(classification_report(y_test, y_pred_mlp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       903
#            1       0.87      0.88      0.88       925
#
#     accuracy                           0.87      1828
#    macro avg       0.87      0.87      0.87      1828
# weighted avg       0.87      0.87      0.87      1828

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_mlp = confusion_matrix(y_test, y_pred_mlp)
sns.heatmap(confusion_matrix_mlp,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_mlp):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_mlp)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_mlp = accuracy_score(y_test, y_pred_mlp)
precision_mlp = precision_score(y_test, y_pred_mlp)
recall_mlp = recall_score(y_test, y_pred_mlp)
f1_mlp = f1_score(y_test, y_pred_mlp)
kappa_mlp = cohen_kappa_score(y_test, y_pred_mlp)
specificity_mlp = specificity_score(y_test, y_pred_mlp)
log_loss_mlp = log_loss(y_test, y_pred_mlp)
roc_auc_score_mlp = roc_auc_score(y_test, y_pred_mlp)

print("Accuracy:", accuracy_mlp)
print("Precision:", precision_mlp)
print("Recall:", recall_mlp)
print("F1 Score:", f1_mlp)
print("Kappa:", kappa_mlp)
print("Specificity:", specificity_mlp)
print("AUC:", roc_auc_score_mlp)
print("Log Loss:", log_loss_mlp)
# Out:
# Accuracy: 0.8741794310722101
# Precision: 0.8748651564185544
# Recall: 0.8767567567567568
# F1 Score: 0.8758099352051836
# Kappa: 0.7483157797697224
# Specificity: 0.8715393133997785
# AUC: 0.8741480350782677
# Log Loss: 4.535032975654784

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_mlp, tpr_mlp, _ = roc_curve(y_test, y_pred_mlp)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_mlp = roc_auc_score(y_test, y_pred_mlp)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_mlp, tpr_mlp, color='darkorange', lw=2, label=f'ROC curve (area = {auc_mlp:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(MLP)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Combined ROC Curve

# %%
# Plotting ROC curves for multiple algorithms
plt.figure(figsize=(8, 6))
plt.plot(fpr_svm, tpr_svm, color='indigo', lw=2, label=f'SVM({auc_svm:0.2f})')
plt.plot(fpr_lr, tpr_lr, color='red', lw=2, label=f'LR({auc_lr:0.2f})')
plt.plot(fpr_rf, tpr_rf, color='magenta', lw=2, label=f'RF({auc_rf:0.2f})')
plt.plot(fpr_knn, tpr_knn, color='green', lw=2, label=f'KNN({auc_knn:0.2f})')
plt.plot(fpr_xgb, tpr_xgb, color='blue', lw=2, label=f'XGBoost({auc_xgb:0.2f})')
plt.plot(fpr_cb, tpr_cb, color='gold', lw=2, label=f'CatBoost({auc_cb:0.2f})')
plt.plot(fpr_mlp, tpr_mlp, color='cyan', lw=2, label=f'MLP({auc_mlp:0.2f})')
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
