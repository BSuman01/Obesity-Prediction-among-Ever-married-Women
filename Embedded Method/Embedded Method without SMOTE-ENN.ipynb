# %% [markdown]
# # Embedded Method Without SMOTE-ENN

# %% [markdown]
# ## Import Essential Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from imblearn.combine import SMOTEENN
from sklearn.model_selection import train_test_split , GridSearchCV , KFold
from sklearn.linear_model import Lasso, LassoCV
from sklearn.feature_selection import SelectKBest
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, make_scorer, confusion_matrix, log_loss
from sklearn.inspection import permutation_importance
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## Import Data

# %%
# Import  the SPSS data file
df=pd.read_spss("E:\Data Analysis\BDHS_2017-2018.sav")
# Displaying the first 5 rows of the DataFrame
df.head()
# Out:
#     V013      V024   V025       V106          V701   V130  V151  \
# 0  15-19  Rajshahi  Rural  Secondary  No education  Islam  Male
# 1  45-49   Rangpur  Urban    Primary  No education  Islam  Male
# 2  15-19    Khulna  Rural  Secondary       Primary  Islam  Male
# 3  40-44   Barisal  Urban    Primary       Primary  Islam  Male
# 4  25-29   Barisal  Rural  Secondary        Higher  Islam  Male
#
#                   V201 V123 V124  ...     V190    V190A      V113      V116  \
# 0             No child   No   No  ...  Poorest  Poorest  Improved  Improved
# 1  More than two child   No   No  ...  Poorest  Poorest  Improved  Improved
# 2            One child   No   No  ...   Poorer   Poorer  Improved  Improved
# 3  More than two child   No   No  ...  Poorest  Poorest  Improved  Improved
# 4            One child   No   No  ...   Richer  Richest  Improved  Improved
#
#          V161          V213 V404                           V743A  \
# 0  Solid fuel  No or unsure   No  Respondent and husband/partner
# 1  Solid fuel  No or unsure   No  Respondent and husband/partner
# 2  Solid fuel  No or unsure  Yes  Respondent and husband/partner
# 3  Solid fuel  No or unsure   No  Respondent and husband/partner
# 4  Solid fuel           Yes   No  Respondent and husband/partner
#
#                   V312                BMI2
# 0       Modern methods  Underweight/Normal
# 1  Traditional methods  Underweight/Normal
# 2       Modern methods  Underweight/Normal
# 3            Not using  Underweight/Normal
# 4            Not using  Underweight/Normal
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Get some Basic Information

# %%
# Displaying a summary of the DataFrame, including the number of non-null entries and data types for each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16303 entries, 0 to 16302
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V013    16303 non-null  category
#  1   V024    16303 non-null  category
#  2   V025    16303 non-null  category
#  3   V106    16303 non-null  category
#  4   V701    16303 non-null  category
#  5   V130    16303 non-null  category
#  6   V151    16303 non-null  category
#  7   V201    16303 non-null  category
#  8   V123    16303 non-null  category
#  9   V124    16303 non-null  category
#  10  V125    16303 non-null  category
#  11  V119    16303 non-null  category
#  12  V122    16303 non-null  category
#  13  V121    16303 non-null  category
#  14  V159    16303 non-null  category
#  15  V716    16303 non-null  category
#  16  V704    16303 non-null  category
#  17  V190    16303 non-null  category
#  18  V190A   16303 non-null  category
#  19  V113    16303 non-null  category
#  20  V116    16303 non-null  category
#  21  V161    16303 non-null  category
#  22  V213    16303 non-null  category
#  23  V404    16303 non-null  category
#  24  V743A   16303 non-null  category
#  25  V312    16303 non-null  category
#  26  BMI2    16303 non-null  category
# dtypes: category(27)
# memory usage: 434.4 KB

# %%
# Checking missing values
df.isnull().sum().sum()
# Out:
# 0

# %%
# Checking the dimensions of the DataFrame
df.shape
# Out:
# (16303, 27)

# %%
# Displaying the column labels (names) of the DataFrame
df.columns
# Out:
# Index(['V013', 'V024', 'V025', 'V106', 'V701', 'V130', 'V151', 'V201', 'V123',
#        'V124', 'V125', 'V119', 'V122', 'V121', 'V159', 'V716', 'V704', 'V190',
#        'V190A', 'V113', 'V116', 'V161', 'V213', 'V404', 'V743A', 'V312',
#        'BMI2'],
#       dtype='object')

# %%
# Counting the frequency of each unique value in the 'BMI2' column
df.BMI2.value_counts()
# Out:
# BMI2
# Underweight/Normal    10951
# Overweight/Obese       5352
# Name: count, dtype: int64

# %% [markdown]
# ## Feature Transformation

# %%
# Transform the selected features
V013 = {'15-19': 1, '20-24': 2,'25-29':3,'30-34':4,'35-39':5,'40-44':6,'45-49':7}
df['V013'] = df['V013'].map(V013)
V024 = {'Barisal': 1, 'Chittagong': 2,'Dhaka':3,'Khulna':4,'Mymensingh':5,'Rajshahi':6,'Rangpur':7,'Sylhet':8}
df['V024'] = df['V024'].map(V024)
V025 = {'Urban': 1, 'Rural': 2}
df['V025'] = df['V025'].map(V025)
V106 = {'No education': 0, 'Primary': 1,'Secondary':2,'Higher':3}
df['V106'] = df['V106'].map(V106)
V701= {'No education': 0, 'Primary': 1,'Secondary':2,'Higher':3,"Don't know":4}
df['V701'] = df['V701'].map(V701)
V130 = {'Islam': 0, 'Hinduism': 1,'Buddhism':2,'Christianity':3}
df['V130'] = df['V130'].map(V130)
V151= {'Male': 1, 'Female': 2}
df['V151'] = df['V151'].map(V151)
V201= {'No child': 0, 'One child': 1,'Two child':2,'More than two child':3}
df['V201'] = df['V201'].map(V201)
V123= {'No': 0, 'Yes': 1}
df['V123'] = df['V123'].map(V123)
V124= {'No': 0, 'Yes': 1}
df['V124'] = df['V124'].map(V124)
V125= {'No': 0, 'Yes': 1}
df['V125'] = df['V125'].map(V125)
V119= {'No': 0, 'Yes': 1}
df['V119'] = df['V119'].map(V119)
V122= {'No': 0, 'Yes': 1}
df['V122'] = df['V122'].map(V122)
V121= {'No': 0, 'Yes': 1}
df['V121'] = df['V121'].map(V121)
V159= {'Not at all': 0, 'Less than once a week': 1,'At least once a week':2,'Almost every day':3}
df['V159'] = df['V159'].map(V159)
V716= {'Unemployed': 0, 'Agriculture': 1,'Business':2,'Labor/ Service':3,'Job':4}
df['V716'] = df['V716'].map(V716)
V704= {'Unemployed': 0, 'Agriculture': 1,'Business':2,'Labor/ Service':3,'Job':4}
df['V704'] = df['V704'].map(V704)
V190= {'Poorest': 1, 'Poorer': 2,'Middle':3,'Richer':4,'Richest':5}
df['V190'] = df['V190'].map(V190)
V190A= {'Poorest': 1, 'Poorer': 2,'Middle':3,'Richer':4,'Richest':5}
df['V190A'] = df['V190A'].map(V190A)
V113= {'Improved': 1, 'Unimproved': 2}
df['V113'] = df['V113'].map(V113)
V116= {'Improved': 1, 'Unimproved': 2}
df['V116'] = df['V116'].map(V116)
V161= {'Solid fuel': 0, 'Clean fuel': 1}
df['V161'] = df['V161'].map(V161)
V213= {'No or unsure': 0, 'Yes': 1}
df['V213'] = df['V213'].map(V213)
V404= {'No': 0, 'Yes': 1}
df['V404'] = df['V404'].map(V404)
V743A= {'Respondent alone': 1, 'Respondent and husband/partner': 2, "Respondent and other's person": 3}
df['V743A'] = df['V743A'].map(V743A)
V312= {'Not using': 0, 'Modern methods': 1,'Traditional methods':2}
df['V312'] = df['V312'].map(V312)
BMI2= {'Underweight/Normal': 0, 'Overweight/Obese': 1}
df['BMI2'] = df['BMI2'].map(BMI2)

# %%
# Displaying the first 5 rows of the DataFrame after transformation
df.head()
# Out:
#   V013 V024 V025 V106 V701 V130 V151 V201 V123 V124  ... V190 V190A V113 V116  \
# 0    1    6    2    2    0    0    1    0    0    0  ...    1     1    1    1
# 1    7    7    1    1    0    0    1    3    0    0  ...    1     1    1    1
# 2    1    4    2    2    1    0    1    1    0    0  ...    2     2    1    1
# 3    6    1    1    1    1    0    1    3    0    0  ...    1     1    1    1
# 4    3    1    2    2    3    0    1    1    0    0  ...    4     5    1    1
#
#   V161 V213 V404 V743A V312 BMI2
# 0    0    0    0     2    1    0
# 1    0    0    0     2    2    0
# 2    0    0    1     2    1    0
# 3    0    0    0     2    0    0
# 4    0    1    0     2    0    0
#
# [5 rows x 27 columns]

# %%
# Checking missing values after transformation
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Define Explanatory and Outcome Variable

# %%
# Drop the Outcome variable from the DataFrame in order to create explanatory variavle
x=df.drop(["BMI2"],axis=1)
y=df["BMI2"]

# %%
# Checking the dimensions of the explanatory and outcome variable
x.shape, y.shape
# Out:
# ((16303, 26), (16303,))

# %% [markdown]
# ## Explanatory Data Analysis (EDA)

# %% [markdown]
# ### BMI2 Graph

# %%
# Calculate the counts for each category in y
counts = np.bincount(y)

# Set up the figure and 3D axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Define the X, Y, and Z coordinates for the bars
X = np.arange(len(counts))  # [0, 1] for two categories
Y = np.zeros_like(X)  # Y values are all zeros, used just for plotting
Z = np.zeros_like(X)  # Z values are the base of the bars, all zeros

# Define the width, depth, and height of the bars
dx = np.ones_like(X)
dy = np.ones_like(Y)
dz = counts

# Create the bars
ax.bar3d(X, Y, Z, dx, dy, dz, color=['cyan', 'magenta'], zsort='average')

# Set labels and title
ax.set_xticks(X)
ax.set_xticklabels(BMI2)
# Set labels and title with Times New Roman font style
font = {'fontname': 'Times New Roman'}
# Show the plot
plt.show()

# %% [markdown]
# ### Correlation

# %%
# Calculating and displaying the correlation matrix, showing the correlation coefficients between the features of the DataFrame
corr=df.corr()
corr
# Out:
#            V013      V024      V025      V106      V701      V130      V151  \
# V013   1.000000  0.012270  0.000005 -0.372709 -0.180281  0.041279 -0.016666
# V024   0.012270  1.000000  0.072954 -0.084455 -0.084267  0.055474 -0.079159
# V025   0.000005  0.072954  1.000000 -0.150652 -0.178218  0.002744  0.042323
# V106  -0.372709 -0.084455 -0.150652  1.000000  0.624033  0.037122  0.034919
# V701  -0.180281 -0.084267 -0.178218  0.624033  1.000000  0.057236  0.045746
# V130   0.041279  0.055474  0.002744  0.037122  0.057236  1.000000 -0.053993
# V151  -0.016666 -0.079159  0.042323  0.034919  0.045746 -0.053993  1.000000
# V201   0.628503  0.015849  0.085681 -0.406391 -0.290724 -0.042693  0.004826
# V123   0.057086  0.147911  0.112747  0.043280  0.041009  0.024064 -0.091827
# V124  -0.008857  0.066598 -0.055957  0.225866  0.256817  0.009224 -0.066338
# V125   0.014769  0.001107 -0.065821  0.069399  0.066194 -0.006172 -0.014038
col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_cc5f6_row1_col7, #T_cc5f6_row17_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_cc5f6_row1_col8, #T_cc5f6_row1_col21, #T_cc5f6_row5_col7, #T_cc5f6_row6_col0, #T_cc5f6_row6_col4, #T_cc5f6_row21_col23, #T_cc5f6_row23_col17, #T_cc5f6_row24_col22 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_cc5f6_row1_col9, #T_cc5f6_row1_col14, #T_cc5f6_row3_col24, #T_cc5f6_row8_col9, #T_cc5f6_row8_col24, #T_cc5f6_row9_col8, #T_cc5f6_row12_col25, #T_cc5f6_row16_col9, #T_cc5f6_row23_col13, #T_cc5f6_row23_col14 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_cc5f6_row1_col10, #T_cc5f6_row19_col15, #T_cc5f6_row21_col5, #T_cc5f6_row24_col10, #T_cc5f6_row25_col10 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_cc5f6_row1_col12, #T_cc5f6_row3_col20, #T_cc5f6_row5_col9, #T_cc5f6_row8_col26, #T_cc5f6_row11_col24, #T_cc5f6_row12_col2, #T_cc5f6_row17_col24, #T_cc5f6_row21_col10 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_cc5f6_row1_col15, #T_cc5f6_row8_col15, #T_cc5f6_row10_col1, #T_cc5f6_row11_col10, #T_cc5f6_row13_col5, #T_cc5f6_row14_col5, #T_cc5f6_row15_col24, #T_cc5f6_row19_col26, #T_cc5f6_row24_col26 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_cc5f6_row1_col17, #T_cc5f6_row1_col18, #T_cc5f6_row1_col25, #T_cc5f6_row3_col26, #T_cc5f6_row6_col13, #T_cc5f6_row9_col26, #T_cc5f6_row13_col23, #T_cc5f6_row21_col25, #T_cc5f6_row23_col25 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_cc5f6_row1_col19, #T_cc5f6_row3_col5, #T_cc5f6_row7_col19, #T_cc5f6_row12_col20, #T_cc5f6_row19_col1, #T_cc5f6_row23_col19 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_cc5f6_row1_col22, #T_cc5f6_row8_col21, #T_cc5f6_row10_col9, #T_cc5f6_row17_col23, #T_cc5f6_row20_col22, #T_cc5f6_row24_col25 {
#   background-color: #84a7

# %% [markdown]
# ## Feature Selection: Embedded Method (LASSO)

# %%
# Initialize a Lasso model with an alpha value 0.01 regularization strength
lasso_model = Lasso(alpha=0.01) 
lasso_model.fit(x,y)
# Out:
# Lasso(alpha=0.01)

# %%
# Retrieve the coefficients of the features from the fitted Lasso model
feature_coefs = lasso_model.coef_
# Create a DataFrame to display the feature names alongside their corresponding Lasso coefficients
coefficients_df = pd.DataFrame({
    'Feature': x.columns,
    'Lasso Coefficient': feature_coefs
})
print(coefficients_df)
# Out:
#    Feature  Lasso Coefficient
# 0     V013           0.040525
# 1     V024          -0.010544
# 2     V025          -0.002007
# 3     V106           0.015682
# 4     V701           0.016351
# 5     V130          -0.000000
# 6     V151          -0.000000
# 7     V201           0.001406
# 8     V123          -0.000000
# 9     V124           0.000000
# 10    V125           0.000000
# 11    V119          -0.000000
# 12    V122           0.041700
# 13    V121           0.000000
# 14    V159           0.012575
# 15    V716          -0.000000
# 16    V704           0.007101
# 17    V190           0.058330
# 18   V190A           0.000000
# 19    V113          -0.000000
# 20    V116          -0.000000
# 21    V161           0.000250
# 22    V213           0.000000
# 23    V404          -0.029117
# 24   V743A          -0.000000
# 25    V312           0.000000

# %%
# Identify the features that have non-zero coefficients in the Lasso model
important_features = x.columns[feature_coefs != 0]
# Display the important features
important_features
# Out:
# Index(['V013', 'V024', 'V025', 'V106', 'V701', 'V201', 'V122', 'V159', 'V704',
#        'V190', 'V161', 'V404'],
#       dtype='object')

# %%
# Create a new DataFrame containing only the important features
x_selected = x[important_features]

# %% [markdown]
# ## Train-Test Spliting

# %%
# Spliting the data set into training and testing subsets
x_train, x_test, y_train, y_test = train_test_split(x_selected, y, random_state=42, stratify= y, test_size=.2)

# %%
# Checking the dimensions of the training and testing subsets
x_train.shape, x_test.shape
# Out:
# ((13042, 12), (3261, 12))

# %%
# Checking the dimensions of the training and testing subsets
y_train.shape, y_test.shape
# Out:
# ((13042,), (3261,))

# %%
x_train.head()
# Out:
#       V013 V024 V025 V106 V701 V201 V122 V159 V704 V190 V161 V404
# 6171     2    2    2    2    3    2    1    0    3    5    0    0
# 10899    6    3    2    1    1    3    0    0    1    1    0    0
# 8380     7    6    2    1    2    2    1    2    3    4    0    0
# 33       4    1    2    2    0    2    0    2    3    3    0    0
# 2904     7    5    2    2    2    3    0    0    1    3    0    0

# %%
y_train.head()
# Out:
# 6171     1
# 10899    0
# 8380     0
# 33       0
# 2904     1
# Name: BMI2, dtype: category
# Categories (2, int64): [1, 0]

# %% [markdown]
# ## (Default) Classification Algorithm in Machine Learning

# %% [markdown]
# ### 1. Support Vector Machine (SVM)

# %%
# Initialize the SVM model
model_svm=SVC()
model_svm.fit(x_train, y_train) 
y_pred = model_svm.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.91      0.82      2190
#            1       0.66      0.34      0.45      1071
#
#     accuracy                           0.73      3261
#    macro avg       0.70      0.63      0.63      3261
# weighted avg       0.71      0.73      0.70      3261

# %%
# Printing the default parameters
print(model_svm.get_params())
# Out:
# {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': False, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_svm= accuracy_score(y_test, y_pred)
precision_svm = precision_score(y_test, y_pred)
recall_svm = recall_score(y_test, y_pred)
f1_svm = f1_score(y_test, y_pred)
kappa_svm = cohen_kappa_score(y_test, y_pred)
specificity_svm = specificity_score(y_test, y_pred)
log_loss_svm = log_loss(y_test, y_pred)
roc_auc_score_svm = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_svm)
print("Precision:", precision_svm)
print("Recall:", recall_svm)
print("F1 Score:", f1_svm)
print("Kappa:",kappa_svm)
print("Specificity:", specificity_svm)
print("AUC:", roc_auc_score_svm)
print("Log Loss:", log_loss_svm)
# Out:
# Accuracy: 0.7255443115608708
# Precision: 0.6594202898550725
# Recall: 0.33986928104575165
# F1 Score: 0.4485520640788663
# Kappa: 0.2899173985619745
# Specificity: 0.9141552511415525
# AUC: 0.6270122660936521
# Log Loss: 9.892385704771497

# %% [markdown]
# ### 2. Logistic Regression (LR)

# %%
# Initialize the SVM model
model_lr=LogisticRegression()
model_lr.fit(x_train, y_train) 
y_pred = model_lr.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.90      0.81      2190
#            1       0.62      0.34      0.44      1071
#
#     accuracy                           0.71      3261
#    macro avg       0.68      0.62      0.62      3261
# weighted avg       0.70      0.71      0.69      3261

# %%
# Printing the default parameters
print(model_lr.get_params())
# Out:
# {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'auto', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_lr= accuracy_score(y_test, y_pred)
precision_lr = precision_score(y_test, y_pred)
recall_lr = recall_score(y_test, y_pred)
f1_lr = f1_score(y_test, y_pred)
kappa_lr = cohen_kappa_score(y_test, y_pred)
specificity_lr = specificity_score(y_test, y_pred)
log_loss_lr = log_loss(y_test, y_pred)
roc_auc_score_lr = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_lr)
print("Precision:", precision_lr)
print("Recall:", recall_lr)
print("F1 Score:", f1_lr)
print("Kappa:", kappa_lr)
print("Specificity:", specificity_lr)
print("AUC:", roc_auc_score_lr)
print("Log Loss:", log_loss_lr)
# Out:
# Accuracy: 0.7138914443422263
# Precision: 0.6157718120805369
# Recall: 0.3426704014939309
# F1 Score: 0.4403119376124775
# Kappa: 0.2685308532007199
# Specificity: 0.8954337899543379
# AUC: 0.6190520957241344
# Log Loss: 10.312397611789725

# %% [markdown]
# ### 3. Random Forest (RF)

# %%
# Initialize the SVM model
model_rf=RandomForestClassifier()
model_rf.fit(x_train, y_train) 
y_pred = model_rf.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.82      0.77      2190
#            1       0.51      0.40      0.45      1071
#
#     accuracy                           0.68      3261
#    macro avg       0.62      0.61      0.61      3261
# weighted avg       0.66      0.68      0.67      3261

# %%
# Printing the default parameters
print(model_rf.get_params())
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_rf= accuracy_score(y_test, y_pred)
precision_rf = precision_score(y_test, y_pred)
recall_rf = recall_score(y_test, y_pred)
f1_rf = f1_score(y_test, y_pred)
kappa_rf = cohen_kappa_score(y_test, y_pred)
specificity_rf = specificity_score(y_test, y_pred)
log_loss_rf = log_loss(y_test, y_pred)
roc_auc_score_rf = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_rf)
print("Precision:", precision_rf)
print("Recall:", recall_rf)
print("F1 Score:", f1_rf)
print("Kappa:", kappa_rf)
print("Specificity:", specificity_rf)
print("AUC:", roc_auc_score_rf)
print("Log Loss:", log_loss_rf)
# Out:
# Accuracy: 0.6789328426862925
# Precision: 0.5145631067961165
# Recall: 0.39589169000933705
# F1 Score: 0.4474934036939314
# Kappa: 0.22659424313078447
# Specificity: 0.817351598173516
# AUC: 0.6066216440914265
# Log Loss: 11.57243333284442

# %% [markdown]
# ### 4. K-Nearest Neighbor (KNN)

# %%
# Initialize the KNN model
model_knn=KNeighborsClassifier()
model_knn.fit(x_train, y_train) 
y_pred = model_knn.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77      2190
#            1       0.52      0.40      0.45      1071
#
#     accuracy                           0.68      3261
#    macro avg       0.63      0.61      0.61      3261
# weighted avg       0.66      0.68      0.67      3261

# %%
# Printing the default parameters
print(model_knn.get_params())
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_knn= accuracy_score(y_test, y_pred)
precision_knn = precision_score(y_test, y_pred)
recall_knn = recall_score(y_test, y_pred)
f1_knn = f1_score(y_test, y_pred)
kappa_knn = cohen_kappa_score(y_test, y_pred)
specificity_knn = specificity_score(y_test, y_pred)
log_loss_knn = log_loss(y_test, y_pred)
roc_auc_score_knn = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_knn)
print("Precision:", precision_knn)
print("Recall:", recall_knn)
print("F1 Score:", f1_knn)
print("Kappa:", kappa_knn)
print("Specificity:", specificity_knn)
print("AUC:", roc_auc_score_knn)
print("Log Loss:", log_loss_knn)
# Out:
# Accuracy: 0.6798528058877645
# Precision: 0.5160905840286055
# Recall: 0.4042950513538749
# F1 Score: 0.45340314136125653
# Kappa: 0.23173139154194233
# Specificity: 0.8146118721461187
# AUC: 0.6094534617499968
# Log Loss: 11.539274498079827

# %% [markdown]
# ### 5. Extreme Gradient Boosting (XGBoost)

# %%
# Initialize the XGBoost model
model_xgb=xgb.XGBClassifier(enable_categorical=True)
model_xgb.fit(x_train, y_train)
y_pred = model_xgb.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.84      0.79      2190
#            1       0.55      0.41      0.47      1071
#
#     accuracy                           0.70      3261
#    macro avg       0.65      0.62      0.63      3261
# weighted avg       0.68      0.70      0.68      3261

# %%
# Printing the default parameters
print(model_xgb.get_params())
# Out:
# {'objective': 'binary:logistic', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': True, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': None, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': None, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_xgb= accuracy_score(y_test, y_pred)
precision_xgb = precision_score(y_test, y_pred)
recall_xgb = recall_score(y_test, y_pred)
f1_xgb = f1_score(y_test, y_pred)
kappa_xgb = cohen_kappa_score(y_test, y_pred)
specificity_xgb = specificity_score(y_test, y_pred)
log_loss_xgb = log_loss(y_test, y_pred)
roc_auc_score_xgb = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_xgb)
print("Precision:", precision_xgb)
print("Recall:", recall_xgb)
print("F1 Score:", f1_xgb)
print("Kappa:", kappa_xgb)
print("Specificity:", specificity_xgb)
print("AUC:", roc_auc_score_xgb)
print("Log Loss:", log_loss_xgb)
# Out:
# Accuracy: 0.6951855259122969
# Precision: 0.5484276729559748
# Recall: 0.40709617180205415
# F1 Score: 0.46730975348338694
# Kappa: 0.2603073021923554
# Specificity: 0.8360730593607306
# AUC: 0.6215846155813923
# Log Loss: 10.986627252003204

# %% [markdown]
# ### 6. Categorical Boosting (CatBoost)

# %%
# List of categorical feature names to be used in the model
# These features are assumed to be categorical variables in the selected features
cat_features=['V013', 'V024', 'V025', 'V106', 'V701', 'V201', 'V122', 'V159', 'V704', 'V190', 'V161', 'V404']

# %%
# Initialize the CatBoost model
model_cb=CatBoostClassifier(cat_features=cat_features)
model_cb.fit(x_train, y_train)
y_pred = model_cb.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
# Learning rate set to 0.030845
# 0:	learn: 0.6857698	total: 169ms	remaining: 2m 49s
# 1:	learn: 0.6788658	total: 197ms	remaining: 1m 38s
# 2:	learn: 0.6720484	total: 227ms	remaining: 1m 15s
# 3:	learn: 0.6654689	total: 248ms	remaining: 1m 1s
# 4:	learn: 0.6589752	total: 274ms	remaining: 54.5s
# 5:	learn: 0.6531055	total: 299ms	remaining: 49.6s
# 6:	learn: 0.6477810	total: 320ms	remaining: 45.3s
# 7:	learn: 0.6425639	total: 343ms	remaining: 42.5s
# 8:	learn: 0.6380144	total: 368ms	remaining: 40.5s
# 9:	learn: 0.6336227	total: 395ms	remaining: 39.1s
# 10:	learn: 0.6293764	total: 426ms	remaining: 38.3s
# 11:	learn: 0.6257705	total: 460ms	remaining: 37.8s
# 12:	learn: 0.6219446	total: 485ms	remaining: 36.8s
# 13:	learn: 0.6183972	total: 509ms	remaining: 35.8s
# 14:	learn: 0.6152428	total: 530ms	remaining: 34.8s
# 15:	learn: 0.6122112	total: 550ms	remaining: 33.8s
# 16:	learn: 0.6093099	total: 574ms	remaining: 33.2s
# 17:	learn: 0.6065556	total: 604ms	remaining: 33s
# 18:	learn: 0.6041012	total: 633ms	remaining: 32.7s
# 19:	learn: 0.6015378	total: 668ms	remaining: 32.7s
# 20:	learn: 0.5994181	total: 698ms	remaining: 32.5s
# 21:	learn: 0.5973235	total: 723ms	remaining: 32.2s
# 22:	learn: 0.5960188	total: 737ms	remaining: 31.3s
# 23:	learn: 0.5941118	total: 771ms	remaining: 31.3s
# 24:	learn: 0.5923937	total: 800ms	remaining: 31.2s
# 25:	learn: 0.5902970	total: 834ms	remaining: 31.2s
# 262:	learn: 0.5424225	total: 7.28s	remaining: 20.4s
# 263:	learn: 0.5423936	total: 7.31s	remaining: 20.4s
# 264:	learn: 0.5423378	total: 7.34s	remaining: 20.3s
# 265:	learn: 0.5422906	total: 7.36s	remaining: 20.3s
# 266:	learn: 0.5422602	total: 7.39s	remaining: 20.3s
# 267:	learn: 0.5421945	total: 7.42s	remaining: 20.3s
# 268:	learn: 0.5421918	total: 7.44s	remaining: 20.2s
# 269:	learn: 0.5421419	total: 7.47s	remaining: 20.2s
# 270:	learn: 0.5421148	total: 7.5s	remaining: 20.2s
# 271:	learn: 0.5421148	total: 7.51s	remaining: 20.1s
# 272:	learn: 0.5420466	total: 7.54s	remaining: 20.1s
# 273:	learn: 0.5419993	total: 7.56s	remaining: 20s
# 274:	learn: 0.5418797	total: 7.59s	remaining: 20s
# 275:	learn: 0.5418429	total: 7.62s	remaining: 20s
# 276:	learn: 0.5418162	total: 7.64s	remaining: 20s
# 277:	learn: 0.5417630	total: 7.67s	remaining: 19.9s
# 278:	learn: 0.5416893	total: 7.71s	remaining: 19.9s
# 279:	learn: 0.5416593	total: 7.73s	remaining: 19.9s
# 280:	learn: 0.5415158	total: 7.76s	remaining: 19.9s
# 281:	learn: 0.5413918	total: 7.79s	remaining: 19.8s
# 282:	learn: 0.5412728	total: 7.84s	remaining: 19.9s
# 283:	learn: 0.5411715	total: 7.88s	remaining: 19.9s
# 284:	learn: 0.5411506	total: 7.91s	remaining: 19.9s
# 285:	learn: 0.5411129	total: 7.95s	remaining: 19.9s
# 286:	learn: 0.5410467	total: 7.99s	remaining: 19.8s
# 287:	learn: 0.5409845	total: 8.02s	remaining: 19.8s
# 288:	learn: 0.5409655	total: 8.05s	remaining: 19.8s
# 289:	learn: 0.5409327	total: 8.09s	remaining: 19.8s
# 290:	learn: 0.5409064	total: 8.12s	remaining: 19.8s
# 291:	learn: 0.5408491	total: 8.15s	remaining: 19.8s
# 292:	learn: 0.5407681	total: 8.18s	remaining: 19.7s
# 293:	learn: 0.5406601	total: 8.21s	remaining: 19.7s
# 294:	learn: 0.5406150	total: 8.24s	remaining: 19.7s
# 295:	learn: 0.5406078	total: 8.25s	remaining: 19.6s
# 296:	learn: 0.5405872	total: 8.28s	remaining: 19.6s
# 297:	learn: 0.5405248	total: 8.31s	remaining: 19.6s
# 298:	learn: 0.5404369	total: 8.34s	remaining: 19.6s
# 299:	learn: 0.5404343	total: 8.36s	remaining: 19.5s
# 300:	learn: 0.5403311	total: 8.39s	remaining: 19.5s
# 301:	learn: 0.5403009	total: 8.42s	remaining: 19.5s
# 302:	learn: 0.5402747	total: 8.45s	remaining: 19.4s
# 303:	learn: 0.5402481	total: 8.48s	remaining: 19.4s
# 304:	learn: 0.5401964	total: 8.51s	remaining: 19.4s
# 305:	learn: 0.5401046	total: 8.54s	remaining: 19.4s
# 306:	learn: 0.5400172	total: 8.58s	remaining: 19.4s
# 307:	learn: 0.5400116	total: 8.61s	remaining: 19.3s
# 355:	learn: 0.5372857	total: 10s	remaining: 18.1s
# 356:	learn: 0.5372254	total: 10.1s	remaining: 18.1s
# 357:	learn: 0.5371795	total: 10.1s	remaining: 18.1s
# 358:	learn: 0.5370987	total: 10.1s	remaining: 18.1s
# 359:	learn: 0.5370268	total: 10.2s	remaining: 18.1s
# 360:	learn: 0.5369764	total: 10.2s	remaining: 18.1s
# 361:	learn: 0.5369301	total: 10.2s	remaining: 18s
# 362:	learn: 0.5369119	total: 10.3s	remaining: 18s
# 363:	learn: 0.5368531	total: 10.3s	remaining: 18s
# 364:	learn: 0.5368294	total: 10.3s	remaining: 17.9s
# 365:	learn: 0.5367504	total: 10.3s	remaining: 17.9s
# 366:	learn: 0.5366958	total: 10.4s	remaining: 17.9s
# 367:	learn: 0.5366517	total: 10.4s	remaining: 17.9s
# 368:	learn: 0.5365760	total: 10.4s	remaining: 17.8s
# 369:	learn: 0.5364830	total: 10.5s	remaining: 17.8s
# 370:	learn: 0.5364181	total: 10.5s	remaining: 17.8s
# 371:	learn: 0.5363406	total: 10.5s	remaining: 17.7s
# 372:	learn: 0.5362421	total: 10.5s	remaining: 17.7s
# 373:	learn: 0.5361600	total: 10.6s	remaining: 17.7s
# 374:	learn: 0.5361468	total: 10.6s	remaining: 17.7s
# 375:	learn: 0.5361215	total: 10.6s	remaining: 17.6s
# 376:	learn: 0.5361136	total: 10.7s	remaining: 17.6s
# 377:	learn: 0.5360659	total: 10.7s	remaining: 17.6s
# 378:	learn: 0.5360047	total: 10.7s	remaining: 17.6s
# 379:	learn: 0.5359369	total: 10.7s	remaining: 17.5s
# 380:	learn: 0.5358647	total: 10.8s	remaining: 17.5s
# 381:	learn: 0.5357810	total: 10.8s	remaining: 17.5s
# 382:	learn: 0.5357616	total: 10.8s	remaining: 17.5s
# 383:	learn: 0.5357184	total: 10.9s	remaining: 17.4s
# 384:	learn: 0.5355934	total: 10.9s	remaining: 17.4s
# 385:	learn: 0.5354235	total: 10.9s	remaining: 17.4s
# 386:	learn: 0.5353699	total: 11s	remaining: 17.3s
# 387:	learn: 0.5353061	total: 11s	remaining: 17.3s
# 388:	learn: 0.5352907	total: 11s	remaining: 17.3s
# 389:	learn: 0.5352561	total: 11s	remaining: 17.3s
# 390:	learn: 0.5351638	total: 11.1s	remaining: 17.2s
# 391:	learn: 0.5351018	total: 11.1s	remaining: 17.2s
# 392:	learn: 0.5350287	total: 11.1s	remaining: 17.2s
# 393:	learn: 0.5349733	total: 11.2s	remaining: 17.2s
# 394:	learn: 0.5349635	total: 11.2s	remaining: 17.1s
# 395:	learn: 0.5349217	total: 11.2s	remaining: 17.1s
# 396:	learn: 0.5348732	total: 11.2s	remaining: 17.1s
# 397:	learn: 0.5348389	total: 11.3s	remaining: 17s
# 398:	learn: 0.5348258	total: 11.3s	remaining: 17s
# 399:	learn: 0.5347566	total: 11.3s	remaining: 17s
# 400:	learn: 0.5347461	total: 11.4s	remaining: 17s
# 401:	learn: 0.5347170	total: 11.4s	remaining: 16.9s
# 402:	learn: 0.5346859	total: 11.4s	remaining: 16.9s
# 544:	learn: 0.5266473	total: 15.8s	remaining: 13.2s
# 545:	learn: 0.5266236	total: 15.8s	remaining: 13.1s
# 546:	learn: 0.5265463	total: 15.8s	remaining: 13.1s
# 547:	learn: 0.5264914	total: 15.9s	remaining: 13.1s
# 548:	learn: 0.5264282	total: 15.9s	remaining: 13s
# 549:	learn: 0.5263793	total: 15.9s	remaining: 13s
# 550:	learn: 0.5263485	total: 16s	remaining: 13s
# 551:	learn: 0.5263125	total: 16s	remaining: 13s
# 552:	learn: 0.5262545	total: 16s	remaining: 13s
# 553:	learn: 0.5261470	total: 16.1s	remaining: 12.9s
# 554:	learn: 0.5261059	total: 16.1s	remaining: 12.9s
# 555:	learn: 0.5260569	total: 16.1s	remaining: 12.9s
# 556:	learn: 0.5260248	total: 16.2s	remaining: 12.8s
# 557:	learn: 0.5259650	total: 16.2s	remaining: 12.8s
# 558:	learn: 0.5259085	total: 16.2s	remaining: 12.8s
# 559:	learn: 0.5258756	total: 16.2s	remaining: 12.8s
# 560:	learn: 0.5258542	total: 16.3s	remaining: 12.7s
# 561:	learn: 0.5258080	total: 16.3s	remaining: 12.7s
# 562:	learn: 0.5257741	total: 16.3s	remaining: 12.7s
# 563:	learn: 0.5257108	total: 16.4s	remaining: 12.6s
# 564:	learn: 0.5256467	total: 16.4s	remaining: 12.6s
# 565:	learn: 0.5256379	total: 16.4s	remaining: 12.6s
# 566:	learn: 0.5255284	total: 16.4s	remaining: 12.6s
# 567:	learn: 0.5255125	total: 16.5s	remaining: 12.5s
# 568:	learn: 0.5254610	total: 16.5s	remaining: 12.5s
# 569:	learn: 0.5254344	total: 16.5s	remaining: 12.5s
# 570:	learn: 0.5253714	total: 16.6s	remaining: 12.4s
# 571:	learn: 0.5253273	total: 16.6s	remaining: 12.4s
# 572:	learn: 0.5252300	total: 16.6s	remaining: 12.4s
# 573:	learn: 0.5251217	total: 16.7s	remaining: 12.4s
# 574:	learn: 0.5250645	total: 16.7s	remaining: 12.3s
# 575:	learn: 0.5249324	total: 16.7s	remaining: 12.3s
# 576:	learn: 0.5248570	total: 16.7s	remaining: 12.3s
# 577:	learn: 0.5248389	total: 16.8s	remaining: 12.3s
# 578:	learn: 0.5248195	total: 16.8s	remaining: 12.2s
# 579:	learn: 0.5247750	total: 16.9s	remaining: 12.2s
# 580:	learn: 0.5247296	total: 16.9s	remaining: 12.2s
# 581:	learn: 0.5247044	total: 16.9s	remaining: 12.2s
# 582:	learn: 0.5246782	total: 17s	remaining: 12.1s
# 583:	learn: 0.5246523	total: 17s	remaining: 12.1s
# 584:	learn: 0.5246024	total: 17.1s	remaining: 12.1s
# 585:	learn: 0.5245434	total: 17.1s	remaining: 12.1s
# 586:	learn: 0.5244469	total: 17.1s	remaining: 12s
# 587:	learn: 0.5244019	total: 17.2s	remaining: 12s
# 588:	learn: 0.5243302	total: 17.2s	remaining: 12s
# 589:	learn: 0.5242351	total: 17.2s	remaining: 12s
# 590:	learn: 0.5241548	total: 17.2s	remaining: 11.9s
# 591:	learn: 0.5240568	total: 17.3s	remaining: 11.9s
# 592:	learn: 0.5240254	total: 17.3s	remaining: 11.9s
# 593:	learn: 0.5239695	total: 17.3s	remaining: 11.8s
# 594:	learn: 0.5238981	total: 17.4s	remaining: 11.8s
# 595:	learn: 0.5238362	total: 17.4s	remaining: 11.8s
# 596:	learn: 0.5238144	total: 17.4s	remaining: 11.8s
# 597:	learn: 0.5237772	total: 17.4s	remaining: 11.7s
# 598:	learn: 0.5237171	total: 17.5s	remaining: 11.7s
# 599:	learn: 0.5236775	total: 17.5s	remaining: 11.7s
# 600:	learn: 0.5236440	total: 17.5s	remaining: 11.6s
# 601:	learn: 0.5235804	total: 17.6s	remaining: 11.6s
# 602:	learn: 0.5235572	total: 17.6s	remaining: 11.6s
# 603:	learn: 0.5235485	total: 17.6s	remaining: 11.6s
# 604:	learn: 0.5235173	total: 17.7s	remaining: 11.5s
# 605:	learn: 0.5234395	total: 17.7s	remaining: 11.5s
# 606:	learn: 0.5233110	total: 17.7s	remaining: 11.5s
# 607:	learn: 0.5232628	total: 17.7s	remaining: 11.4s
# 608:	learn: 0.5232033	total: 17.8s	remaining: 11.4s
# 609:	learn: 0.5231447	total: 17.9s	remaining: 11.4s
# 610:	learn: 0.5230685	total: 18s	remaining: 11.4s
# 611:	learn: 0.5230342	total: 18s	remaining: 11.4s
# 612:	learn: 0.5229663	total: 18.1s	remaining: 11.4s
# 613:	learn: 0.5229554	total: 18.1s	remaining: 11.4s
# 614:	learn: 0.5229119	total: 18.1s	remaining: 11.3s
# 615:	learn: 0.5228203	total: 18.1s	remaining: 11.3s
# 616:	learn: 0.5228123	total: 18.2s	remaining: 11.3s
# 617:	learn: 0.5227435	total: 18.2s	remaining: 11.3s
# 618:	learn: 0.5226852	total: 18.2s	remaining: 11.2s
# 619:	learn: 0.5225266	total: 18.3s	remaining: 11.2s
# 620:	learn: 0.5224753	total: 18.3s	remaining: 11.2s
# 621:	learn: 0.5224507	total: 18.3s	remaining: 11.1s
# 622:	learn: 0.5224216	total: 18.4s	remaining: 11.1s
# 623:	learn: 0.5223776	total: 18.4s	remaining: 11.1s
# 624:	learn: 0.5223243	total: 18.4s	remaining: 11.1s
# 625:	learn: 0.5222560	total: 18.5s	remaining: 11s
# 626:	learn: 0.5222261	total: 18.5s	remaining: 11s
# 627:	learn: 0.5221700	total: 18.5s	remaining: 11s
# 628:	learn: 0.5221207	total: 18.6s	remaining: 11s
# 629:	learn: 0.5221002	total: 18.6s	remaining: 10.9s
# 630:	learn: 0.5220690	total: 18.6s	remaining: 10.9s
# 631:	learn: 0.5220451	total: 18.7s	remaining: 10.9s
# 632:	learn: 0.5219975	total: 18.7s	remaining: 10.8s
# 633:	learn: 0.5219830	total: 18.7s	remaining: 10.8s
# 634:	learn: 0.5219488	total: 18.8s	remaining: 10.8s
# 635:	learn: 0.5218672	total: 18.8s	remaining: 10.8s
# 636:	learn: 0.5218377	total: 18.8s	remaining: 10.7s
# 637:	learn: 0.5218025	total: 18.9s	remaining: 10.7s
# 638:	learn: 0.5217873	total: 18.9s	remaining: 10.7s
# 639:	learn: 0.5217413	total: 18.9s	remaining: 10.6s
# 640:	learn: 0.5216378	total: 18.9s	remaining: 10.6s
# 641:	learn: 0.5215051	total: 19s	remaining: 10.6s
# 642:	learn: 0.5214725	total: 19s	remaining: 10.6s
# 643:	learn: 0.5214168	total: 19s	remaining: 10.5s
# 644:	learn: 0.5213803	total: 19.1s	remaining: 10.5s
# 645:	learn: 0.5213420	total: 19.1s	remaining: 10.5s
# 646:	learn: 0.5212674	total: 19.1s	remaining: 10.4s
# 647:	learn: 0.5212340	total: 19.2s	remaining: 10.4s
# 648:	learn: 0.5211816	total: 19.2s	remaining: 10.4s
# 649:	learn: 0.5210323	total: 19.2s	remaining: 10.4s
# 650:	learn: 0.5210116	total: 19.3s	remaining: 10.3s
# 651:	learn: 0.5209601	total: 19.3s	remaining: 10.3s
# 652:	learn: 0.5208576	total: 19.3s	remaining: 10.3s
# 653:	learn: 0.5208292	total: 19.3s	remaining: 10.2s
# 654:	learn: 0.5207795	total: 19.4s	remaining: 10.2s
# 655:	learn: 0.5207262	total: 19.4s	remaining: 10.2s
# 656:	learn: 0.5206860	total: 19.4s	remaining: 10.1s
# 657:	learn: 0.5205380	total: 19.5s	remaining: 10.1s
# 658:	learn: 0.5204901	total: 19.5s	remaining: 10.1s
# 659:	learn: 0.5203798	total: 19.5s	remaining: 10.1s
# 660:	learn: 0.5203226	total: 19.5s	remaining: 10s
# 661:	learn: 0.5202485	total: 19.6s	remaining: 10s
# 662:	learn: 0.5202075	total: 19.6s	remaining: 9.97s
# 663:	learn: 0.5201015	total: 19.6s	remaining: 9.94s
# 664:	learn: 0.5200254	total: 19.7s	remaining: 9.91s
# 665:	learn: 0.5199975	total: 19.7s	remaining: 9.88s
# 666:	learn: 0.5199553	total: 19.7s	remaining: 9.85s
# 667:	learn: 0.5198925	total: 19.8s	remaining: 9.82s
# 668:	learn: 0.5198659	total: 19.8s	remaining: 9.8s
# 669:	learn: 0.5198017	total: 19.8s	remaining: 9.77s
# 670:	learn: 0.5197456	total: 19.9s	remaining: 9.75s
# 671:	learn: 0.5196941	total: 19.9s	remaining: 9.72s
# 672:	learn: 0.5196002	total: 20s	remaining: 9.7s
# 673:	learn: 0.5195712	total: 20s	remaining: 9.67s
# 674:	learn: 0.5195461	total: 20s	remaining: 9.65s
# 675:	learn: 0.5194663	total: 20.1s	remaining: 9.62s
# 676:	learn: 0.5194253	total: 20.1s	remaining: 9.59s
# 677:	learn: 0.5193951	total: 20.1s	remaining: 9.56s
# 678:	learn: 0.5193323	total: 20.2s	remaining: 9.53s
# 679:	learn: 0.5193222	total: 20.2s	remaining: 9.5s
# 680:	learn: 0.5192874	total: 20.2s	remaining: 9.47s
# 681:	learn: 0.5192603	total: 20.2s	remaining: 9.44s
# 682:	learn: 0.5191756	total: 20.3s	remaining: 9.41s
# 683:	learn: 0.5191562	total: 20.3s	remaining: 9.38s
# 684:	learn: 0.5191039	total: 20.3s	remaining: 9.35s
# 685:	learn: 0.5190628	total: 20.4s	remaining: 9.32s
# 686:	learn: 0.5189426	total: 20.4s	remaining: 9.29s
# 687:	learn: 0.5188981	total: 20.4s	remaining: 9.26s
# 688:	learn: 0.5188803	total: 20.5s	remaining: 9.23s
# 689:	learn: 0.5188301	total: 20.5s	remaining: 9.2s
# 690:	learn: 0.5187813	total: 20.5s	remaining: 9.17s
# 691:	learn: 0.5187461	total: 20.5s	remaining: 9.14s
# 692:	learn: 0.5187147	total: 20.6s	remaining: 9.11s
# 693:	learn: 0.5186666	total: 20.6s	remaining: 9.08s
# 694:	learn: 0.5185286	total: 20.6s	remaining: 9.05s
# 695:	learn: 0.5184957	total: 20.7s	remaining: 9.03s
# 696:	learn: 0.5184553	total: 20.7s	remaining: 9s
# 697:	learn: 0.5183664	total: 20.7s	remaining: 8.97s
# 698:	learn: 0.5183235	total: 20.8s	remaining: 8.94s
# 699:	learn: 0.5182938	total: 20.8s	remaining: 8.91s
# 700:	learn: 0.5182459	total: 20.8s	remaining: 8.88s
# 701:	learn: 0.5182053	total: 20.8s	remaining: 8.85s
# 702:	learn: 0.5181120	total: 20.9s	remaining: 8.82s
# 703:	learn: 0.5180499	total: 20.9s	remaining: 8.79s
# 704:	learn: 0.5179558	total: 20.9s	remaining: 8.76s
# 705:	learn: 0.5179412	total: 21s	remaining: 8.73s
# 706:	learn: 0.5178725	total: 21s	remaining: 8.71s
# 707:	learn: 0.5178543	total: 21s	remaining: 8.68s
# 708:	learn: 0.5177781	total: 21.1s	remaining: 8.65s
# 709:	learn: 0.5177112	total: 21.1s	remaining: 8.62s
# 710:	learn: 0.5176840	total: 21.1s	remaining: 8.59s
# 711:	learn: 0.5175745	total: 21.2s	remaining: 8.56s
# 712:	learn: 0.5175259	total: 21.2s	remaining: 8.53s
# 713:	learn: 0.5174462	total: 21.2s	remaining: 8.5s
# 714:	learn: 0.5174299	total: 21.3s	remaining: 8.47s
# 715:	learn: 0.5173758	total: 21.3s	remaining: 8.44s
# 716:	learn: 0.5173478	total: 21.3s	remaining: 8.41s
# 717:	learn: 0.5172201	total: 21.3s	remaining: 8.38s
# 718:	learn: 0.5171724	total: 21.4s	remaining: 8.35s
# 719:	learn: 0.5170920	total: 21.4s	remaining: 8.32s
# 720:	learn: 0.5170615	total: 21.4s	remaining: 8.29s
# 721:	learn: 0.5170340	total: 21.5s	remaining: 8.26s
# 722:	learn: 0.5169808	total: 21.5s	remaining: 8.23s
# 723:	learn: 0.5169135	total: 21.5s	remaining: 8.2s
# 724:	learn: 0.5168871	total: 21.5s	remaining: 8.17s
# 725:	learn: 0.5168063	total: 21.6s	remaining: 8.14s
# 726:	learn: 0.5167866	total: 21.6s	remaining: 8.12s
# 727:	learn: 0.5166805	total: 21.6s	remaining: 8.09s
# 728:	learn: 0.5166189	total: 21.7s	remaining: 8.06s
# 729:	learn: 0.5165478	total: 21.7s	remaining: 8.03s
# 730:	learn: 0.5164981	total: 21.7s	remaining: 8s
# 731:	learn: 0.5164511	total: 21.8s	remaining: 7.97s
# 779:	learn: 0.5137500	total: 23.4s	remaining: 6.6s
# 780:	learn: 0.5137072	total: 23.4s	remaining: 6.57s
# 781:	learn: 0.5136800	total: 23.5s	remaining: 6.54s
# 782:	learn: 0.5136034	total: 23.5s	remaining: 6.51s
# 783:	learn: 0.5135353	total: 23.5s	remaining: 6.48s
# 784:	learn: 0.5135198	total: 23.5s	remaining: 6.45s
# 785:	learn: 0.5134897	total: 23.6s	remaining: 6.42s
# 786:	learn: 0.5134079	total: 23.6s	remaining: 6.39s
# 787:	learn: 0.5133760	total: 23.6s	remaining: 6.36s
# 788:	learn: 0.5132953	total: 23.7s	remaining: 6.33s
# 789:	learn: 0.5132521	total: 23.7s	remaining: 6.3s
# 790:	learn: 0.5131858	total: 23.7s	remaining: 6.27s
# 791:	learn: 0.5131764	total: 23.8s	remaining: 6.24s
# 792:	learn: 0.5130551	total: 23.8s	remaining: 6.21s
# 793:	learn: 0.5130240	total: 23.8s	remaining: 6.18s
# 794:	learn: 0.5129680	total: 23.9s	remaining: 6.15s
# 795:	learn: 0.5128854	total: 23.9s	remaining: 6.13s
# 796:	learn: 0.5128450	total: 23.9s	remaining: 6.1s
# 797:	learn: 0.5128209	total: 24s	remaining: 6.07s
# 798:	learn: 0.5127748	total: 24s	remaining: 6.04s
# 799:	learn: 0.5127391	total: 24s	remaining: 6.01s
# 800:	learn: 0.5126886	total: 24.1s	remaining: 5.98s
# 801:	learn: 0.5126492	total: 24.1s	remaining: 5.95s
# 802:	learn: 0.5126276	total: 24.1s	remaining: 5.92s
# 803:	learn: 0.5125589	total: 24.2s	remaining: 5.89s
# 804:	learn: 0.5124447	total: 24.2s	remaining: 5.86s
# 805:	learn: 0.5124116	total: 24.2s	remaining: 5.83s
# 806:	learn: 0.5124045	total: 24.3s	remaining: 5.8s
# 807:	learn: 0.5123804	total: 24.3s	remaining: 5.77s
# 808:	learn: 0.5123607	total: 24.3s	remaining: 5.74s
# 809:	learn: 0.5122964	total: 24.3s	remaining: 5.71s
# 810:	learn: 0.5122479	total: 24.4s	remaining: 5.68s
# 811:	learn: 0.5122131	total: 24.4s	remaining: 5.65s
# 812:	learn: 0.5121356	total: 24.4s	remaining: 5.62s
# 813:	learn: 0.5120577	total: 24.5s	remaining: 5.6s
# 814:	learn: 0.5120305	total: 24.5s	remaining: 5.57s
# 815:	learn: 0.5120235	total: 24.5s	remaining: 5.54s
# 816:	learn: 0.5118879	total: 24.6s	remaining: 5.5s
# 817:	learn: 0.5118416	total: 24.6s	remaining: 5.47s
# 818:	learn: 0.5117739	total: 24.6s	remaining: 5.45s
# 819:	learn: 0.5117429	total: 24.7s	remaining: 5.42s
# 820:	learn: 0.5117120	total: 24.7s	remaining: 5.39s
# 821:	learn: 0.5116958	total: 24.7s	remaining: 5.36s
# 822:	learn: 0.5116424	total: 24.8s	remaining: 5.33s
# 823:	learn: 0.5116214	total: 24.8s	remaining: 5.3s
# 824:	learn: 0.5115925	total: 24.8s	remaining: 5.26s
# 825:	learn: 0.5115538	total: 24.9s	remaining: 5.24s
# 920:	learn: 0.5060763	total: 28.2s	remaining: 2.42s
# 921:	learn: 0.5060401	total: 28.2s	remaining: 2.39s
# 922:	learn: 0.5059582	total: 28.3s	remaining: 2.36s
# 923:	learn: 0.5059030	total: 28.3s	remaining: 2.33s
# 924:	learn: 0.5058382	total: 28.3s	remaining: 2.3s
# 925:	learn: 0.5058092	total: 28.4s	remaining: 2.27s
# 926:	learn: 0.5058063	total: 28.4s	remaining: 2.23s
# 927:	learn: 0.5057741	total: 28.4s	remaining: 2.21s
# 928:	learn: 0.5057329	total: 28.5s	remaining: 2.17s
# 929:	learn: 0.5057013	total: 28.5s	remaining: 2.14s
# 930:	learn: 0.5056175	total: 28.5s	remaining: 2.11s
# 931:	learn: 0.5055925	total: 28.6s	remaining: 2.08s
# 932:	learn: 0.5055587	total: 28.6s	remaining: 2.05s
# 933:	learn: 0.5055519	total: 28.6s	remaining: 2.02s
# 934:	learn: 0.5055292	total: 28.7s	remaining: 2s
# 935:	learn: 0.5054893	total: 28.8s	remaining: 1.97s
# 936:	learn: 0.5054224	total: 28.8s	remaining: 1.94s
# 937:	learn: 0.5053618	total: 28.8s	remaining: 1.91s
# 938:	learn: 0.5053333	total: 28.9s	remaining: 1.88s
# 939:	learn: 0.5052382	total: 28.9s	remaining: 1.84s
# 940:	learn: 0.5051756	total: 28.9s	remaining: 1.81s
# 941:	learn: 0.5051190	total: 29s	remaining: 1.78s
# 942:	learn: 0.5049568	total: 29s	remaining: 1.75s
# 943:	learn: 0.5048979	total: 29s	remaining: 1.72s
# 944:	learn: 0.5047866	total: 29.1s	remaining: 1.69s
# 945:	learn: 0.5047556	total: 29.1s	remaining: 1.66s
# 946:	learn: 0.5046071	total: 29.2s	remaining: 1.63s
# 947:	learn: 0.5045368	total: 29.2s	remaining: 1.6s
# 948:	learn: 0.5044917	total: 29.2s	remaining: 1.57s
# 949:	learn: 0.5044553	total: 29.3s	remaining: 1.54s
# 950:	learn: 0.5044017	total: 29.3s	remaining: 1.51s
# 951:	learn: 0.5043035	total: 29.3s	remaining: 1.48s
# 952:	learn: 0.5042804	total: 29.4s	remaining: 1.45s
# 953:	learn: 0.5042736	total: 29.4s	remaining: 1.42s
# 954:	learn: 0.5042367	total: 29.4s	remaining: 1.39s
# 955:	learn: 0.5041991	total: 29.5s	remaining: 1.36s
# 956:	learn: 0.5041832	total: 29.5s	remaining: 1.32s
# 957:	learn: 0.5041426	total: 29.5s	remaining: 1.29s
# 958:	learn: 0.5040665	total: 29.6s	remaining: 1.26s
# 959:	learn: 0.5040187	total: 29.6s	remaining: 1.23s
# 960:	learn: 0.5039748	total: 29.6s	remaining: 1.2s
# 961:	learn: 0.5039152	total: 29.7s	remaining: 1.17s
# 962:	learn: 0.5038532	total: 29.7s	remaining: 1.14s
# 963:	learn: 0.5037880	total: 29.7s	remaining: 1.11s
# 964:	learn: 0.5037556	total: 29.8s	remaining: 1.08s
# 965:	learn: 0.5037416	total: 29.8s	remaining: 1.05s
# 966:	learn: 0.5036536	total: 29.8s	remaining: 1.02s
# 967:	learn: 0.5035890	total: 29.9s	remaining: 987ms
# 968:	learn: 0.5035047	total: 29.9s	remaining: 957ms
# 969:	learn: 0.5034235	total: 29.9s	remaining: 926ms
# 970:	learn: 0.5033669	total: 30s	remaining: 895ms
# 971:	learn: 0.5033055	total: 30s	remaining: 865ms
# 972:	learn: 0.5032306	total: 30.1s	remaining: 834ms
# 973:	learn: 0.5031857	total: 30.1s	remaining: 803ms
# 974:	learn: 0.5031618	total: 30.1s	remaining: 772ms
# 975:	learn: 0.5031368	total: 30.1s	remaining: 741ms
# 976:	learn: 0.5030663	total: 30.2s	remaining: 710ms
# 977:	learn: 0.5030452	total: 30.2s	remaining: 679ms
# 978:	learn: 0.5029815	total: 30.2s	remaining: 649ms
# 979:	learn: 0.5029368	total: 30.3s	remaining: 618ms
# 980:	learn: 0.5029111	total: 30.3s	remaining: 587ms
# 981:	learn: 0.5028242	total: 30.3s	remaining: 556ms
# 982:	learn: 0.5027129	total: 30.4s	remaining: 525ms
# 983:	learn: 0.5026855	total: 30.4s	remaining: 494ms
# 984:	learn: 0.5026181	total: 30.4s	remaining: 463ms
# 985:	learn: 0.5025574	total: 30.5s	remaining: 432ms
# 986:	learn: 0.5024637	total: 30.5s	remaining: 402ms
# 987:	learn: 0.5024360	total: 30.5s	remaining: 371ms
# 988:	learn: 0.5023396	total: 30.6s	remaining: 340ms
# 989:	learn: 0.5022828	total: 30.6s	remaining: 309ms
# 990:	learn: 0.5022406	total: 30.6s	remaining: 278ms
# 991:	learn: 0.5022228	total: 30.7s	remaining: 247ms
# 992:	learn: 0.5021103	total: 30.7s	remaining: 216ms
# 993:	learn: 0.5020517	total: 30.7s	remaining: 185ms
# 994:	learn: 0.5019924	total: 30.7s	remaining: 155ms
# 995:	learn: 0.5019805	total: 30.8s	remaining: 124ms
# 996:	learn: 0.5019478	total: 30.8s	remaining: 92.7ms
# 997:	learn: 0.5019127	total: 30.8s	remaining: 61.8ms
# 998:	learn: 0.5018160	total: 30.9s	remaining: 30.9ms
# 999:	learn: 0.5017241	total: 30.9s	remaining: 0us
#               precision    recall  f1-score   support
#
#            0       0.74      0.89      0.81      2190
#            1       0.63      0.37      0.46      1071
#
#     accuracy                           0.72      3261
#    macro avg       0.69      0.63      0.64      3261
# weighted avg       0.70      0.72      0.70      3261

# %%
# Printing the default parameters
print(model_cb.get_params())
# Out:
# {'cat_features': ['V013', 'V024', 'V025', 'V106', 'V701', 'V201', 'V122', 'V159', 'V704', 'V190', 'V161', 'V404']}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_cb = accuracy_score(y_test, y_pred)
precision_cb = precision_score(y_test, y_pred)
recall_cb = recall_score(y_test, y_pred)
f1_cb = f1_score(y_test, y_pred)
kappa_cb = cohen_kappa_score(y_test, y_pred)
specificity_cb = specificity_score(y_test, y_pred)
log_loss_cb = log_loss(y_test, y_pred)
roc_auc_score_cb = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_cb)
print("Precision:", precision_cb)
print("Recall:", recall_cb)
print("F1 Score:", f1_cb)
print("Kappa:", kappa_cb)
print("Specificity:", specificity_cb)
print("AUC:", roc_auc_score_cb)
print("Log Loss:", log_loss_cb)
# Out:
# Accuracy: 0.7206378411530205
# Precision: 0.626984126984127
# Recall: 0.36881419234360413
# F1 Score: 0.4644326866549089
# Kappa: 0.29225246164324914
# Specificity: 0.8926940639269406
# AUC: 0.6307541281352724
# Log Loss: 10.069232823516016

# %% [markdown]
# ### 7. Multi-Layer Perceptron (MLP)

# %%
# Initialize the MLP model
model_mlp=MLPClassifier()
model_mlp.fit(x_train, y_train) 
y_pred = model_mlp.predict(x_test) 
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.87      0.81      2190
#            1       0.60      0.40      0.48      1071
#
#     accuracy                           0.72      3261
#    macro avg       0.68      0.64      0.64      3261
# weighted avg       0.70      0.72      0.70      3261

# %%
# Printing the default parameters
print(model_mlp.get_params())
# Out:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': None, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_matrix,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_mlp = accuracy_score(y_test, y_pred)
precision_mlp = precision_score(y_test, y_pred)
recall_mlp = recall_score(y_test, y_pred)
f1_mlp = f1_score(y_test, y_pred)
kappa_mlp = cohen_kappa_score(y_test, y_pred)
specificity_mlp = specificity_score(y_test, y_pred)
log_loss_mlp = log_loss(y_test, y_pred)
roc_auc_score_mlp = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy_mlp)
print("Precision:", precision_mlp)
print("Recall:", recall_mlp)
print("F1 Score:", f1_mlp)
print("Kappa:", kappa_mlp)
print("Specificity:", specificity_mlp)
print("AUC:", roc_auc_score_mlp)
print("Log Loss:", log_loss_mlp)
# Out:
# Accuracy: 0.7169579883471328
# Precision: 0.6039325842696629
# Recall: 0.40149393090569563
# F1 Score: 0.4823331463825014
# Kappa: 0.29826970113019524
# Specificity: 0.8712328767123287
# AUC: 0.6363634038090121
# Log Loss: 10.201868162574405

# %% [markdown]
# ## Hyperparameter Tuned Classification Algorithm

# %% [markdown]
# ### 1. Support Vector Machine (SVM)

# %%
# Optimize the parameter grid for hyperparameter tuning
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
			'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
			'kernel': ['rbf','linear'],
            } 
model_svm=SVC()
# Set up the GridSearchCV to find the best combination of parameters
grid_search_svm= GridSearchCV(estimator=model_svm, param_grid=param_grid,refit = True, cv=5, n_jobs=-1, verbose=3) 
grid_search_svm.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf', 'linear']},
#              verbose=3)

# %%
# Printing the  parameters
print(grid_search_svm.best_params_) 
print(grid_search_svm.best_estimator_)
# Out:
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# SVC(C=1000, gamma=0.001)

# %%
# Print the classification report
y_pred_svm = grid_search_svm.predict(x_test) 
print(classification_report(y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.90      0.81      2190
#            1       0.64      0.36      0.46      1071
#
#     accuracy                           0.72      3261
#    macro avg       0.69      0.63      0.64      3261
# weighted avg       0.71      0.72      0.70      3261

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_svm = confusion_matrix(y_test, y_pred_svm)
sns.heatmap(confusion_matrix_svm,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_svm):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_svm)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_svm= accuracy_score(y_test, y_pred_svm)
precision_svm = precision_score(y_test, y_pred_svm)
recall_svm = recall_score(y_test, y_pred_svm)
f1_svm = f1_score(y_test, y_pred_svm)
kappa_svm = cohen_kappa_score(y_test, y_pred_svm)
specificity_svm = specificity_score(y_test, y_pred_svm)
log_loss_svm = log_loss(y_test, y_pred_svm)
roc_auc_score_svm = roc_auc_score(y_test, y_pred_svm)

print("Accuracy:", accuracy_svm)
print("Precision:", precision_svm)
print("Recall:", recall_svm)
print("F1 Score:", f1_svm)
print("Kappa:",kappa_svm)
print("Specificity:", specificity_svm)
print("AUC:", roc_auc_score_svm)
print("Log Loss:", log_loss_svm)
# Out:
# Accuracy: 0.7221711131554738
# Precision: 0.6381909547738693
# Recall: 0.3557422969187675
# F1 Score: 0.4568345323741007
# Kappa: 0.2898898084735424
# Specificity: 0.9013698630136986
# AUC: 0.6285560799662331
# Log Loss: 10.013968098908352

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_svm, tpr_svm, _ = roc_curve(y_test, y_pred_svm)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_svm = roc_auc_score(y_test, y_pred_svm)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_svm, tpr_svm, color='darkorange', lw=2, label=f'ROC curve (area = {auc_svm:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(SVM)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### 2. Logistic Regression (LR)

# %%
# Optimize the parameter grid for hyperparameter tuning
param_grid={
"penalty" : ["l1","elasticnet"],
"solver" : ["lbfgs","liblinear","sag","saga"],
"max_iter" : [100,300,500,1000],
'C':np.linspace(0,1,30)
}
model_lr = LogisticRegression(random_state= 42)
# Set up the GridSearchCV to find the best combination of parameters
grid_search_lr = GridSearchCV(estimator= model_lr, param_grid= param_grid, cv=5, scoring= 'accuracy', n_jobs=-1, verbose=1)
grid_search_lr.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 960 candidates, totalling 4800 fits
# GridSearchCV(cv=5, estimator=LogisticRegression(random_state=42), n_jobs=-1,
#              param_grid={'C': array([0.        , 0.03448276, 0.06896552, 0.10344828, 0.13793103,
#        0.17241379, 0.20689655, 0.24137931, 0.27586207, 0.31034483,
#        0.34482759, 0.37931034, 0.4137931 , 0.44827586, 0.48275862,
#        0.51724138, 0.55172414, 0.5862069 , 0.62068966, 0.65517241,
#        0.68965517, 0.72413793, 0.75862069, 0.79310345, 0.82758621,
#        0.86206897, 0.89655172, 0.93103448, 0.96551724, 1.        ]),
#                          'max_iter': [100, 300, 500, 1000],
#                          'penalty': ['l1', 'elasticnet'],
#                          'solver': ['lbfgs', 'liblinear', 'sag', 'saga']},
#              scoring='accuracy', verbose=1)

# %%
# Printing the best parameters and estimators
print(grid_search_lr.best_params_) 
print(grid_search_lr.best_estimator_)
# Out:
# {'C': 0.06896551724137931, 'max_iter': 100, 'penalty': 'l1', 'solver': 'saga'}
# LogisticRegression(C=0.06896551724137931, penalty='l1', random_state=42,
#                    solver='saga')

# %%
# Print the classification report
y_pred_lr = grid_search_lr.predict(x_test) 
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.90      0.81      2190
#            1       0.62      0.34      0.44      1071
#
#     accuracy                           0.72      3261
#    macro avg       0.68      0.62      0.62      3261
# weighted avg       0.70      0.72      0.69      3261

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_lr = confusion_matrix(y_test, y_pred_lr)
sns.heatmap(confusion_matrix_lr,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_lr):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_lr)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_lr= accuracy_score(y_test, y_pred_lr)
precision_lr = precision_score(y_test, y_pred_lr)
recall_lr = recall_score(y_test, y_pred_lr)
f1_lr = f1_score(y_test, y_pred_lr)
kappa_lr = cohen_kappa_score(y_test, y_pred_lr)
specificity_lr = specificity_score(y_test, y_pred_lr)
log_loss_lr = log_loss(y_test, y_pred_lr)
roc_auc_score_lr = roc_auc_score(y_test, y_pred_lr)

print("Accuracy:", accuracy_lr)
print("Precision:", precision_lr)
print("Recall:", recall_lr)
print("F1 Score:", f1_lr)
print("Kappa:", kappa_lr)
print("Specificity:", specificity_lr)
print("AUC:", roc_auc_score_lr)
print("Log Loss:", log_loss_lr)
# Out:
# Accuracy: 0.7157313707451702
# Precision: 0.6232876712328768
# Recall: 0.33986928104575165
# F1 Score: 0.4398791540785498
# Kappa: 0.27088101452306035
# Specificity: 0.8995433789954338
# AUC: 0.6197063300205927
# Log Loss: 10.246079942260533

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_lr, tpr_lr, _ = roc_curve(y_test, y_pred_lr)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_lr = roc_auc_score(y_test, y_pred_lr)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_lr, tpr_lr, color='darkorange', lw=2, label=f'ROC curve (area = {auc_lr:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(LR)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### 3. Random Forest (RF)

# %%
# Optimize the parameter grid for hyperparameter tuning
param_grid = { 
	'n_estimators': [25, 50, 100, 150], 
	'max_features': ['sqrt', 'log2'], 
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False],  
    'criterion': ['gini', 'entropy']  
}
model_rf = RandomForestClassifier(random_state=42)
# Set up the GridSearchCV to find the best combination of parameters
grid_search_rf = GridSearchCV(estimator= model_rf, param_grid= param_grid, refit=True, cv=5, verbose=True, n_jobs=-1,scoring='accuracy')
grid_search_rf.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [25, 50, 100, 150]},
#              scoring='accuracy', verbose=True)

# %%
# Printing the best parameters and estimators
print(grid_search_rf.best_params_) 
print(grid_search_rf.best_estimator_)
# Out:
# {'bootstrap': True, 'criterion': 'entropy', 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 150}
# RandomForestClassifier(criterion='entropy', min_samples_leaf=4,
#                        n_estimators=150, random_state=42)

# %%
# Print the classification report
y_pred_rf = grid_search_rf.predict(x_test) 
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.89      0.81      2190
#            1       0.64      0.37      0.47      1071
#
#     accuracy                           0.72      3261
#    macro avg       0.69      0.63      0.64      3261
# weighted avg       0.71      0.72      0.70      3261

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_rf = confusion_matrix(y_test, y_pred_rf)
sns.heatmap(confusion_matrix_rf,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_rf):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_rf)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_rf= accuracy_score(y_test, y_pred_rf)
precision_rf = precision_score(y_test, y_pred_rf)
recall_rf = recall_score(y_test, y_pred_rf)
f1_rf = f1_score(y_test, y_pred_rf)
kappa_rf = cohen_kappa_score(y_test, y_pred_rf)
specificity_rf = specificity_score(y_test, y_pred_rf)
log_loss_rf = log_loss(y_test, y_pred_rf)
roc_auc_score_rf = roc_auc_score(y_test, y_pred_rf)

print("Accuracy:", accuracy_rf)
print("Precision:", precision_rf)
print("Recall:", recall_rf)
print("F1 Score:", f1_rf)
print("Kappa:", kappa_rf)
print("Specificity:", specificity_rf)
print("AUC:", roc_auc_score_rf)
print("Log Loss:", log_loss_rf)
# Out:
# Accuracy: 0.7240110395584176
# Precision: 0.6354992076069731
# Recall: 0.37441643323996265
# F1 Score: 0.4712103407755582
# Kappa: 0.3009846092287466
# Specificity: 0.8949771689497716
# AUC: 0.6346968010948671
# Log Loss: 9.94765042937916

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_rf, tpr_rf, _ = roc_curve(y_test, y_pred_rf)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_rf = roc_auc_score(y_test, y_pred_rf)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_rf, tpr_rf, color='darkorange', lw=2, label=f'ROC curve (area = {auc_rf:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(RF)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Feature Importance

# %%
# Compute permutation importance
perm_importance= permutation_importance(grid_search_rf, x_test, y_test, n_repeats=30, random_state=42)
importance_df = pd.DataFrame(perm_importance.importances_mean, index=x_selected.columns, columns=["Importance"])
importance_df = importance_df.sort_values(by="Importance", ascending=False)
# Display the results
print(importance_df)
# Out:
#       Importance
# V013    0.027456
# V122    0.020270
# V190    0.012644
# V024    0.009465
# V404    0.008300
# V201    0.006879
# V025    0.005285
# V161    0.005121
# V704    0.005050
# V701    0.004733
# V106    0.004477
# V159    0.000450

# %% [markdown]
# ### 4. K-Nearest Neighbor (KNN)

# %%
# Optimize the parameter grid for hyperparameter tuning
param_grid = {
    "n_neighbors" : [3,4,5,8,10],
    'metric': ['euclidean', 'manhattan'],
    "weights" : ["uniform","distance"],
    "algorithm" : ["auto","ball_tree","kd_tree","brute"],
    "leaf_size" : [10,20,30,40,50],
}
model_knn = KNeighborsClassifier()
# Set up the GridSearchCV to find the best combination of parameters
grid_search_knn= GridSearchCV(estimator= model_knn, param_grid= param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search_knn.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 400 candidates, totalling 2000 fits
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'leaf_size': [10, 20, 30, 40, 50],
#                          'metric': ['euclidean', 'manhattan'],
#                          'n_neighbors': [3, 4, 5, 8, 10],
#                          'weights': ['uniform', 'distance']},
#              verbose=2)

# %%
# Printing the best parameters and estimators
print(grid_search_knn.best_params_) 
print(grid_search_knn.best_estimator_)
# Out:
# {'algorithm': 'ball_tree', 'leaf_size': 30, 'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# KNeighborsClassifier(algorithm='ball_tree', metric='euclidean', n_neighbors=10)

# %%
# Print the classification report
y_pred_knn = grid_search_knn.predict(x_test) 
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.89      0.80      2190
#            1       0.58      0.31      0.41      1071
#
#     accuracy                           0.70      3261
#    macro avg       0.65      0.60      0.60      3261
# weighted avg       0.68      0.70      0.67      3261

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_knn = confusion_matrix(y_test, y_pred_knn)
sns.heatmap(confusion_matrix_knn,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_knn):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_knn)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_knn= accuracy_score(y_test, y_pred_knn)
precision_knn = precision_score(y_test, y_pred_knn)
recall_knn = recall_score(y_test, y_pred_knn)
f1_knn = f1_score(y_test, y_pred_knn)
kappa_knn = cohen_kappa_score(y_test, y_pred_knn)
specificity_knn = specificity_score(y_test, y_pred_knn)
log_loss_knn = log_loss(y_test, y_pred_knn)
roc_auc_score_knn = roc_auc_score(y_test, y_pred_knn)

print("Accuracy:", accuracy_knn)
print("Precision:", precision_knn)
print("Recall:", recall_knn)
print("F1 Score:", f1_knn)
print("Kappa:", kappa_knn)
print("Specificity:", specificity_knn)
print("AUC:", roc_auc_score_knn)
print("Log Loss:", log_loss_knn)
# Out:
# Accuracy: 0.7010119595216191
# Precision: 0.583916083916084
# Recall: 0.3118580765639589
# F1 Score: 0.4065733414485697
# Kappa: 0.23063549112798032
# Specificity: 0.891324200913242
# AUC: 0.6015911387386005
# Log Loss: 10.776621298494089

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_knn, tpr_knn, _ = roc_curve(y_test, y_pred_knn)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_knn = roc_auc_score(y_test, y_pred_knn)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_knn, tpr_knn, color='darkorange', lw=2, label=f'ROC curve (area = {auc_knn:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(KNN)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### 5. Extreme Gradient Boosting (XGBoost)

# %%
# Optimize the parameter grid for hyperparameter tuning
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 4, 5, 6],
    'min_child_weight': [1, 2, 3],
    'subsample': [0.6, 0.7, 0.8, 0.9],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9],
    'gamma': [0, 0.1, 0.2]
}
model_xgb = xgb.XGBClassifier(enable_categorical=True, random_state=42)
# Set up the GridSearchCV to find the best combination of parameters
grid_search_xgb = GridSearchCV(estimator= model_xgb, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search_xgb.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 5184 candidates, totalling 25920 fits
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=True, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, m...
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=42, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.6, 0.7, 0.8, 0.9],
#                          'gamma': [0, 0.1, 0.2],
#                          'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 4, 5, 6],
#                          'min_child_weight': [1, 2, 3],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.6, 0.7, 0.8, 0.9]},
#              verbose=2)

# %%
# Printing the best parameters and estimators
print(grid_search_xgb.best_params_) 
print(grid_search_xgb.best_estimator_)
# Out:
# {'colsample_bytree': 0.6, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 300, 'subsample': 0.7}
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               gamma=0, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=2, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
# Print the classification report
y_pred_xgb = grid_search_xgb.predict(x_test) 
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.91      0.82      2190
#            1       0.65      0.35      0.45      1071
#
#     accuracy                           0.72      3261
#    macro avg       0.69      0.63      0.63      3261
# weighted avg       0.71      0.72      0.70      3261

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_xgb = confusion_matrix(y_test, y_pred_xgb)
sns.heatmap(confusion_matrix_xgb,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_xgb):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_xgb)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_xgb= accuracy_score(y_test, y_pred_xgb)
precision_xgb = precision_score(y_test, y_pred_xgb)
recall_xgb = recall_score(y_test, y_pred_xgb)
f1_xgb = f1_score(y_test, y_pred_xgb)
kappa_xgb = cohen_kappa_score(y_test, y_pred_xgb)
specificity_xgb = specificity_score(y_test, y_pred_xgb)
log_loss_xgb = log_loss(y_test, y_pred_xgb)
roc_auc_score_xgb = roc_auc_score(y_test, y_pred_xgb)

print("Accuracy:", accuracy_xgb)
print("Precision:", precision_xgb)
print("Recall:", recall_xgb)
print("F1 Score:", f1_xgb)
print("Kappa:", kappa_xgb)
print("Specificity:", specificity_xgb)
print("AUC:", roc_auc_score_xgb)
print("Log Loss:", log_loss_xgb)
# Out:
# Accuracy: 0.7233977307574364
# Precision: 0.6474694589877836
# Recall: 0.3464052287581699
# F1 Score: 0.451338199513382
# Kappa: 0.28843186690528966
# Specificity: 0.9077625570776255
# AUC: 0.6270838929178978
# Log Loss: 9.969756319222224

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_xgb, tpr_xgb, _ = roc_curve(y_test, y_pred_xgb)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_xgb = roc_auc_score(y_test, y_pred_xgb)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_xgb, tpr_xgb, color='darkorange', lw=2, label=f'ROC curve (area = {auc_xgb:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(XGBoost)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### 6. Categorical Boosting (CatBoost)

# %%
cat_features = ['V013', 'V024', 'V025', 'V106', 'V701', 'V201', 'V122', 'V159', 'V704', 'V190', 'V161', 'V404']
model_cb = CatBoostClassifier(random_state=42, verbose=False,cat_features = cat_features )
# Optimize the parameter grid for hyperparameter tuning
param_grid = {
    'depth': [4, 6, 8],
    'learning_rate': [0.01, 0.05, 0.1],
    'iterations': [100, 200, 300],
    'l2_leaf_reg': [1, 3, 5, 7, 9]
}
# Set up the GridSearchCV to find the best combination of parameters
grid_search_cb = GridSearchCV(estimator= model_cb, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search_cb.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# GridSearchCV(cv=5,
#              estimator=<catboost.core.CatBoostClassifier object at 0x0000028CB3BB5580>,
#              n_jobs=-1,
#              param_grid={'depth': [4, 6, 8], 'iterations': [100, 200, 300],
#                          'l2_leaf_reg': [1, 3, 5, 7, 9],
#                          'learning_rate': [0.01, 0.05, 0.1]},
#              verbose=2)

# %%
# Printing the best parameters and estimators
print(grid_search_cb.best_params_) 
print(grid_search_cb.best_estimator_)
# Out:
# {'depth': 4, 'iterations': 200, 'l2_leaf_reg': 9, 'learning_rate': 0.05}
# <catboost.core.CatBoostClassifier object at 0x0000028CA561F650>

# %%
# Print the classification report
y_pred_cb = grid_search_cb.predict(x_test) 
print(classification_report(y_test, y_pred_cb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.89      0.81      2190
#            1       0.63      0.37      0.46      1071
#
#     accuracy                           0.72      3261
#    macro avg       0.68      0.63      0.64      3261
# weighted avg       0.70      0.72      0.70      3261

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_cb = confusion_matrix(y_test, y_pred_cb)
sns.heatmap(confusion_matrix_cb,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_cb):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_cb)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_cb = accuracy_score(y_test, y_pred_cb)
precision_cb = precision_score(y_test, y_pred_cb)
recall_cb = recall_score(y_test, y_pred_cb)
f1_cb = f1_score(y_test, y_pred_cb)
kappa_cb = cohen_kappa_score(y_test, y_pred_cb)
specificity_cb = specificity_score(y_test, y_pred_cb)
log_loss_cb = log_loss(y_test, y_pred_cb)
roc_auc_score_cb = roc_auc_score(y_test, y_pred_cb)

print("Accuracy:", accuracy_cb)
print("Precision:", precision_cb)
print("Recall:", recall_cb)
print("F1 Score:", f1_cb)
print("Kappa:", kappa_cb)
print("Specificity:", specificity_cb)
print("AUC:", roc_auc_score_cb)
print("Log Loss:", log_loss_cb)
# Out:
# Accuracy: 0.7200245323520392
# Precision: 0.6257961783439491
# Recall: 0.36694677871148457
# F1 Score: 0.46262507357268984
# Kappa: 0.2903202969635038
# Specificity: 0.8926940639269406
# AUC: 0.6298204213192126
# Log Loss: 10.09133871335908

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_cb, tpr_cb, _ = roc_curve(y_test, y_pred_cb)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_cb = roc_auc_score(y_test, y_pred_cb)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_cb, tpr_cb, color='darkorange', lw=2, label=f'ROC curve (area = {auc_cb:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(CatBoost)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### 7. Multi-Layer Perceptron (MLP)

# %%
# Optimize the parameter grid for hyperparameter tuning
param_grid= {
   'hidden_layer_sizes': [(50,), (50,50), (100,),(100,50)],
    'activation': ['tanh', 'relu','logistic'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001,0.001,.01, 0.05],
    'learning_rate': ['constant','adaptive','invscaling'],
}
model_mlp=MLPClassifier(random_state=42)
# Set up the GridSearchCV to find the best combination of parameters
grid_search_mlp= GridSearchCV( estimator= model_mlp, param_grid=param_grid, cv = 5, n_jobs=-1, verbose=2)
grid_search_mlp.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# GridSearchCV(cv=5, estimator=MLPClassifier(random_state=42), n_jobs=-1,
#              param_grid={'activation': ['tanh', 'relu', 'logistic'],
#                          'alpha': [0.0001, 0.001, 0.01, 0.05],
#                          'hidden_layer_sizes': [(50,), (50, 50), (100,),
#                                                 (100, 50)],
#                          'learning_rate': ['constant', 'adaptive',
#                                            'invscaling'],
#                          'solver': ['sgd', 'adam']},
#              verbose=2)

# %%
# Printing the best parameters and estimators
print(grid_search_mlp.best_params_) 
print(grid_search_mlp.best_estimator_)
# Out:
# {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# MLPClassifier(activation='logistic', hidden_layer_sizes=(50, 50),
#               random_state=42)

# %%
# Print the classification report
y_pred_mlp = grid_search_mlp.predict(x_test) 
print(classification_report(y_test, y_pred_mlp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.89      0.81      2190
#            1       0.63      0.37      0.46      1071
#
#     accuracy                           0.72      3261
#    macro avg       0.69      0.63      0.64      3261
# weighted avg       0.71      0.72      0.70      3261

# %%
# Calculating and Visualizing the confusion matrix using heatmap
confusion_matrix_mlp = confusion_matrix(y_test, y_pred_mlp)
sns.heatmap(confusion_matrix_mlp,annot=True,fmt="d")
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix
# Define a function to calculate the specificity score
def specificity_score(y_test, y_pred_mlp):
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred_mlp)
    tn = cm[0, 0] 
    fp = cm[0, 1]
    return tn / (tn + fp)

# %%
# Printing the performance evaluation
accuracy_mlp = accuracy_score(y_test, y_pred_mlp)
precision_mlp = precision_score(y_test, y_pred_mlp)
recall_mlp = recall_score(y_test, y_pred_mlp)
f1_mlp = f1_score(y_test, y_pred_mlp)
kappa_mlp = cohen_kappa_score(y_test, y_pred_mlp)
specificity_mlp = specificity_score(y_test, y_pred_mlp)
log_loss_mlp = log_loss(y_test, y_pred_mlp)
roc_auc_score_mlp = roc_auc_score(y_test, y_pred_mlp)

print("Accuracy:", accuracy_mlp)
print("Precision:", precision_mlp)
print("Recall:", recall_mlp)
print("F1 Score:", f1_mlp)
print("Kappa:", kappa_mlp)
print("Specificity:", specificity_mlp)
print("AUC:", roc_auc_score_mlp)
print("Log Loss:", log_loss_mlp)
# Out:
# Accuracy: 0.7212511499540019
# Precision: 0.6302250803858521
# Recall: 0.3660130718954248
# F1 Score: 0.4630832841110455
# Kappa: 0.2922969266922745
# Specificity: 0.8949771689497716
# AUC: 0.6304951204225983
# Log Loss: 10.04712693367295

# %%
# Calculating the False Positive Rate (FPR) and True Positive Rate (TPR) for the ROC curve
fpr_mlp, tpr_mlp, _ = roc_curve(y_test, y_pred_mlp)
# Calculating the Area Under the Curve (AUC) for the ROC curve
auc_mlp = roc_auc_score(y_test, y_pred_mlp)

# %%
# Plotting the ROC curve with the FPR and TPR values
plt.figure()
plt.plot(fpr_mlp, tpr_mlp, color='darkorange', lw=2, label=f'ROC curve (area = {auc_mlp:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic(MLP)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Combined ROC Curve

# %%
# Plotting ROC curves for multiple algorithms
plt.figure(figsize=(8, 6))
plt.plot(fpr_svm, tpr_svm, color='indigo', lw=2, label=f'SVM({auc_svm:0.2f})')
plt.plot(fpr_lr, tpr_lr, color='red', lw=2, label=f'LR({auc_lr:0.2f})')
plt.plot(fpr_rf, tpr_rf, color='magenta', lw=2, label=f'RF({auc_rf:0.2f})')
plt.plot(fpr_knn, tpr_knn, color='green', lw=2, label=f'KNN({auc_knn:0.2f})')
plt.plot(fpr_xgb, tpr_xgb, color='blue', lw=2, label=f'XGBoost({auc_xgb:0.2f})')
plt.plot(fpr_cb, tpr_cb, color='gold', lw=2, label=f'CatBoost({auc_cb:0.2f})')
plt.plot(fpr_mlp, tpr_mlp, color='cyan', lw=2, label=f'MLP({auc_mlp:0.2f})')
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
